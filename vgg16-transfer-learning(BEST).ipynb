# %% [markdown]
# # 1. Import Libraries

# %%
import os
import keras
import itertools
import numpy as np
import pandas as pd
import seaborn as sn
from collections import Counter
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten, Dropout,BatchNormalization ,Activation, GlobalAveragePooling2D
from tensorflow.keras.layers import GaussianNoise
from tensorflow.keras import regularizers

import keras.backend as K
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.callbacks import ReduceLROnPlateau,ModelCheckpoint,EarlyStopping

from IPython.display import Image, HTML
from tensorflow.keras.utils import plot_model

# %% [markdown]
# # 2. Parameter

# %%
# declare path
train_dir = '../archive/train'
test_dir = '../archive/test'

# Image size

IMAGE_SIZE = (48,48)
IMAGE_SHAPE = IMAGE_SIZE + (3,)

BS = 64
EPOCHS = 100
ADAM_LEARNING_RATE = 0.0001
PATIENCE =10

classes=['Angry','Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %% [markdown]
# # 3. Prepare data

# %%
# Data augmentation

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
                                   featurewise_center=False,
                                   featurewise_std_normalization=False,
                                   rotation_range=10,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.1,
                                   horizontal_flip=True)

test_datagen  = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255)

# %%
# Load datasat

train_dataset  = train_datagen.flow_from_directory(directory = train_dir,
                                                   target_size = IMAGE_SIZE,
                                                   class_mode = 'categorical',
                                                   batch_size = BS)

test_dataset = test_datagen.flow_from_directory(directory = test_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  shuffle =True,
                                                  batch_size = BS)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # 4. Explore data

# %%
# Data labels

class_labels = test_dataset.class_indices
class_labels
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
# See the shape of any data

train_sample=next(train_dataset)
print(train_sample[0].shape)
# Out:
# (64, 48, 48, 3)

# %%
# Plot image of each class

plt.figure(figsize=(14,22))
i = 1
for expression in os.listdir(train_dir):
    print(train_dir + "/" + expression + '/' + os.listdir(train_dir +"/"+ expression)[1])
    img = load_img((train_dir + "/" + expression + '/' + os.listdir(train_dir +"/"+ expression)[1]))
    plt.subplot(1,7,i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()
# Out:
# archive/train/angry/Training_10120469.jpg
# archive/train/disgust/Training_10598340.jpg
# archive/train/fear/Training_10031494.jpg
# archive/train/happy/Training_10046809.jpg
# archive/train/neutral/Training_10031781.jpg
# archive/train/sad/Training_10031481.jpg
# archive/train/surprise/Training_1002457.jpg

# %% [markdown]
# # 5. Model

# %%
# VGG16

base_model = tf.keras.applications.VGG16(input_shape= IMAGE_SHAPE,include_top=False,weights="imagenet")
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 48, 48, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 48, 48, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 24, 24, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 24, 24, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 24, 24, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 12, 12, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 12, 12, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 6, 6, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 6, 6, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Freezing Layers

for layer in base_model.layers[:11]:
    layer.trainable=False

# %%
# Build transfer learning Model

model=tf.keras.models.Sequential()
model.add(base_model)
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.GaussianNoise(0.01))
model.add(tf.keras.layers.GlobalAveragePooling2D())

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(256, activation='relu',kernel_regularizer=tf.keras.regularizers.l2(0.001),bias_regularizer=tf.keras.regularizers.l2(0.001)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.5))

model.add(tf.keras.layers.Dense(128, activation='relu',kernel_regularizer=tf.keras.regularizers.l2(0.001),bias_regularizer=tf.keras.regularizers.l2(0.001)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.5))

model.add(tf.keras.layers.Dense(7, activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 1, 1, 512)         14714688
#
#  batch_normalization (BatchN  (None, 1, 1, 512)        2048
#  ormalization)
#
#  gaussian_noise (GaussianNoi  (None, 1, 1, 512)        0
#  se)
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 14,883,399
# Trainable params: 13,146,119
# Non-trainable params: 1,737,280
# _________________________________________________________________

# %%
# Model trainable

print("Model trainable",len(model.trainable_variables))
# Out:
# Model trainable 24

# %%
# Compile model

def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

METRICS = [
      'accuracy',
    #   tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      f1_score,
]

adam = tf.keras.optimizers.Adam(learning_rate=ADAM_LEARNING_RATE, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

model.compile(optimizer=adam, loss='categorical_crossentropy',metrics=METRICS)

# %%
# Run Model

# counter = Counter(train_dataset.classes)                          
# max_val = float(max(counter.values()))       
# class_weights = {class_id : round(max_val/num_images,2) for class_id, num_images in counter.items()}  

# lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = PATIENCE,verbose = 1,factor = 0.50, min_lr = 1e-10)
# mcp = ModelCheckpoint('model.h5')
es = tf.keras.callbacks.EarlyStopping(verbose=1, patience=18)

history=model.fit(train_dataset,
                  validation_data=test_dataset,
                  epochs = EPOCHS,
                  verbose =1,
                  callbacks=[es])
# Out:
# Epoch 1/100
# 449/449 [==============================] - 45s 86ms/step - loss: 3.0477 - accuracy: 0.2308 - precision: 0.2678 - recall: 0.1343 - auc: 0.5991 - f1_score: 0.1785 - val_loss: 4.3526 - val_accuracy: 0.3082 - val_precision: 0.3521 - val_recall: 0.2278 - val_auc: 0.6388 - val_f1_score: 0.2756
# Epoch 2/100
# 449/449 [==============================] - 25s 57ms/step - loss: 2.3782 - accuracy: 0.3605 - precision: 0.4793 - recall: 0.2328 - auc: 0.7305 - f1_score: 0.3128 - val_loss: 2.7350 - val_accuracy: 0.2825 - val_precision: 0.3197 - val_recall: 0.2388 - val_auc: 0.6848 - val_f1_score: 0.2720
# Epoch 3/100
# 449/449 [==============================] - 27s 60ms/step - loss: 2.0746 - accuracy: 0.4188 - precision: 0.5816 - recall: 0.2627 - auc: 0.7848 - f1_score: 0.3611 - val_loss: 1.8759 - val_accuracy: 0.4717 - val_precision: 0.6151 - val_recall: 0.3465 - val_auc: 0.8285 - val_f1_score: 0.4416
# Epoch 4/100
# 449/449 [==============================] - 33s 73ms/step - loss: 1.9098 - accuracy: 0.4588 - precision: 0.6348 - recall: 0.2768 - auc: 0.8150 - f1_score: 0.3846 - val_loss: 2.0059 - val_accuracy: 0.3789 - val_precision: 0.7234 - val_recall: 0.1599 - val_auc: 0.7725 - val_f1_score: 0.2603
# Epoch 5/100
# 449/449 [==============================] - 30s 67ms/step - loss: 1.7991 - accuracy: 0.4860 - precision: 0.6683 - recall: 0.3027 - auc: 0.8344 - f1_score: 0.4157 - val_loss: 1.6935 - val_accuracy: 0.4893 - val_precision: 0.6679 - val_recall: 0.3331 - val_auc: 0.8560 - val_f1_score: 0.4448
# Epoch 6/100
# 449/449 [==============================] - 32s 72ms/step - loss: 1.7156 - accuracy: 0.5040 - precision: 0.6839 - recall: 0.3248 - auc: 0.8480 - f1_score: 0.4394 - val_loss: 1.6638 - val_accuracy: 0.5231 - val_precision: 0.6811 - val_recall: 0.3976 - val_auc: 0.8607 - val_f1_score: 0.5018
# Epoch 7/100
# 449/449 [==============================] - 36s 80ms/step - loss: 1.6452 - accuracy: 0.5248 - precision: 0.6973 - recall: 0.3427 - auc: 0.8582 - f1_score: 0.4587 - val_loss: 1.6087 - val_accuracy: 0.5209 - val_precision: 0.7801 - val_recall: 0.2772 - val_auc: 0.8620 - val_f1_score: 0.4035
# Epoch 8/100
# 449/449 [==============================] - 39s 87ms/step - loss: 1.5927 - accuracy: 0.5376 - precision: 0.6985 - recall: 0.3583 - auc: 0.8654 - f1_score: 0.4726 - val_loss: 1.5844 - val_accuracy: 0.5329 - val_precision: 0.6901 - val_recall: 0.3899 - val_auc: 0.8683 - val_f1_score: 0.4989
# Epoch 9/100
# 449/449 [==============================] - 39s 88ms/step - loss: 1.5312 - accuracy: 0.5508 - precision: 0.7054 - recall: 0.3782 - auc: 0.8740 - f1_score: 0.4915 - val_loss: 1.4390 - val_accuracy: 0.5698 - val_precision: 0.7476 - val_recall: 0.4023 - val_auc: 0.8903 - val_f1_score: 0.5225
# Epoch 10/100
# 449/449 [==============================] - 41s 91ms/step - loss: 1.4870 - accuracy: 0.5645 - precision: 0.7157 - recall: 0.3952 - auc: 0.8797 - f1_score: 0.5083 - val_loss: 1.4737 - val_accuracy: 0.5580 - val_precision: 0.7572 - val_recall: 0.3550 - val_auc: 0.8780 - val_f1_score: 0.4811
# Epoch 11/100
# 449/449 [==============================] - 34s 75ms/step - loss: 1.4284 - accuracy: 0.5774 - precision: 0.7299 - recall: 0.4180 - auc: 0.8877 - f1_score: 0.5309 - val_loss: 1.3807 - val_accuracy: 0.5974 - val_precision: 0.7519 - val_recall: 0.4196 - val_auc: 0.8957 - val_f1_score: 0.5387
# Epoch 12/100
# 449/449 [==============================] - 35s 78ms/step - loss: 1.3916 - accuracy: 0.5872 - precision: 0.7303 - recall: 0.4312 - auc: 0.8923 - f1_score: 0.5416 - val_loss: 1.4184 - val_accuracy: 0.5733 - val_precision: 0.7098 - val_recall: 0.4344 - val_auc: 0.8878 - val_f1_score: 0.5355
# Epoch 13/100
# 449/449 [==============================] - 32s 70ms/step - loss: 1.3548 - accuracy: 0.5938 - precision: 0.7328 - recall: 0.4426 - auc: 0.8966 - f1_score: 0.5510 - val_loss: 1.3687 - val_accuracy: 0.5848 - val_precision: 0.7158 - val_recall: 0.4583 - val_auc: 0.8929 - val_f1_score: 0.5569
# Epoch 14/100
# 449/449 [==============================] - 34s 76ms/step - loss: 1.3060 - accuracy: 0.6083 - precision: 0.7405 - recall: 0.4619 - auc: 0.9029 - f1_score: 0.5680 - val_loss: 1.3192 - val_accuracy: 0.6002 - val_precision: 0.7142 - val_recall: 0.4845 - val_auc: 0.9007 - val_f1_score: 0.5782
# Epoch 15/100
# 449/449 [==============================] - 30s 66ms/step - loss: 1.2568 - accuracy: 0.6234 - precision: 0.7486 - recall: 0.4809 - auc: 0.9097 - f1_score: 0.5848 - val_loss: 1.3641 - val_accuracy: 0.5839 - val_precision: 0.6686 - val_recall: 0.4845 - val_auc: 0.8931 - val_f1_score: 0.5615
# Epoch 16/100
# 449/449 [==============================] - 29s 65ms/step - loss: 1.2166 - accuracy: 0.6343 - precision: 0.7548 - recall: 0.4975 - auc: 0.9146 - f1_score: 0.5991 - val_loss: 1.2552 - val_accuracy: 0.6163 - val_precision: 0.7222 - val_recall: 0.5263 - val_auc: 0.9091 - val_f1_score: 0.6084
# Epoch 17/100
# 449/449 [==============================] - 28s 63ms/step - loss: 1.1826 - accuracy: 0.6415 - precision: 0.7566 - recall: 0.5143 - auc: 0.9183 - f1_score: 0.6117 - val_loss: 1.3360 - val_accuracy: 0.5844 - val_precision: 0.6965 - val_recall: 0.4777 - val_auc: 0.8931 - val_f1_score: 0.5678
# Epoch 18/100
# 449/449 [==============================] - 28s 63ms/step - loss: 1.1422 - accuracy: 0.6556 - precision: 0.7695 - recall: 0.5334 - auc: 0.9230 - f1_score: 0.6294 - val_loss: 1.2382 - val_accuracy: 0.6180 - val_precision: 0.7014 - val_recall: 0.5284 - val_auc: 0.9098 - val_f1_score: 0.6008
# Epoch 19/100
# 449/449 [==============================] - 30s 66ms/step - loss: 1.1023 - accuracy: 0.6708 - precision: 0.7739 - recall: 0.5564 - auc: 0.9277 - f1_score: 0.6468 - val_loss: 1.2861 - val_accuracy: 0.6082 - val_precision: 0.6884 - val_recall: 0.5235 - val_auc: 0.9013 - val_f1_score: 0.5950
# Epoch 20/100
# 449/449 [==============================] - 28s 63ms/step - loss: 1.0596 - accuracy: 0.6795 - precision: 0.7790 - recall: 0.5734 - auc: 0.9328 - f1_score: 0.6601 - val_loss: 1.1827 - val_accuracy: 0.6361 - val_precision: 0.7376 - val_recall: 0.5235 - val_auc: 0.9140 - val_f1_score: 0.6126
# Epoch 21/100
# 449/449 [==============================] - 27s 60ms/step - loss: 1.0312 - accuracy: 0.6895 - precision: 0.7873 - recall: 0.5850 - auc: 0.9358 - f1_score: 0.6705 - val_loss: 1.1837 - val_accuracy: 0.6330 - val_precision: 0.7307 - val_recall: 0.5394 - val_auc: 0.9133 - val_f1_score: 0.6218
# Epoch 22/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.9891 - accuracy: 0.7013 - precision: 0.7881 - recall: 0.6060 - auc: 0.9403 - f1_score: 0.6847 - val_loss: 1.1924 - val_accuracy: 0.6332 - val_precision: 0.7182 - val_recall: 0.5561 - val_auc: 0.9123 - val_f1_score: 0.6245
# Epoch 23/100
# 449/449 [==============================] - 32s 71ms/step - loss: 0.9377 - accuracy: 0.7195 - precision: 0.8000 - recall: 0.6313 - auc: 0.9463 - f1_score: 0.7052 - val_loss: 1.3050 - val_accuracy: 0.5907 - val_precision: 0.6756 - val_recall: 0.5033 - val_auc: 0.8921 - val_f1_score: 0.5763
# Epoch 24/100
# 449/449 [==============================] - 28s 63ms/step - loss: 0.9096 - accuracy: 0.7279 - precision: 0.8069 - recall: 0.6429 - auc: 0.9489 - f1_score: 0.7152 - val_loss: 1.1583 - val_accuracy: 0.6421 - val_precision: 0.7260 - val_recall: 0.5651 - val_auc: 0.9159 - val_f1_score: 0.6347
# Epoch 25/100
# 449/449 [==============================] - 29s 63ms/step - loss: 0.8701 - accuracy: 0.7387 - precision: 0.8142 - recall: 0.6619 - auc: 0.9530 - f1_score: 0.7297 - val_loss: 1.1826 - val_accuracy: 0.6365 - val_precision: 0.7085 - val_recall: 0.5699 - val_auc: 0.9123 - val_f1_score: 0.6295
# Epoch 26/100
# 449/449 [==============================] - 28s 61ms/step - loss: 0.8373 - accuracy: 0.7526 - precision: 0.8184 - recall: 0.6807 - auc: 0.9560 - f1_score: 0.7429 - val_loss: 1.1995 - val_accuracy: 0.6346 - val_precision: 0.6932 - val_recall: 0.5744 - val_auc: 0.9107 - val_f1_score: 0.6282
# Epoch 27/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.8071 - accuracy: 0.7596 - precision: 0.8241 - recall: 0.6943 - auc: 0.9588 - f1_score: 0.7534 - val_loss: 1.1933 - val_accuracy: 0.6434 - val_precision: 0.7021 - val_recall: 0.5924 - val_auc: 0.9150 - val_f1_score: 0.6434
# Epoch 28/100
# 449/449 [==============================] - 26s 59ms/step - loss: 0.7781 - accuracy: 0.7698 - precision: 0.8301 - recall: 0.7068 - auc: 0.9613 - f1_score: 0.7632 - val_loss: 1.2378 - val_accuracy: 0.6378 - val_precision: 0.6990 - val_recall: 0.5825 - val_auc: 0.9070 - val_f1_score: 0.6358
# Epoch 29/100
# 449/449 [==============================] - 26s 57ms/step - loss: 0.7353 - accuracy: 0.7833 - precision: 0.8390 - recall: 0.7239 - auc: 0.9654 - f1_score: 0.7768 - val_loss: 1.2067 - val_accuracy: 0.6371 - val_precision: 0.6911 - val_recall: 0.5882 - val_auc: 0.9116 - val_f1_score: 0.6365
# Epoch 30/100
# 449/449 [==============================] - 26s 57ms/step - loss: 0.7044 - accuracy: 0.7933 - precision: 0.8443 - recall: 0.7404 - auc: 0.9678 - f1_score: 0.7886 - val_loss: 1.2572 - val_accuracy: 0.6152 - val_precision: 0.6872 - val_recall: 0.5515 - val_auc: 0.9004 - val_f1_score: 0.6100
# Epoch 31/100
# 449/449 [==============================] - 25s 56ms/step - loss: 0.6794 - accuracy: 0.7978 - precision: 0.8487 - recall: 0.7487 - auc: 0.9700 - f1_score: 0.7952 - val_loss: 1.2364 - val_accuracy: 0.6395 - val_precision: 0.6867 - val_recall: 0.5997 - val_auc: 0.9108 - val_f1_score: 0.6379
# Epoch 32/100
# 449/449 [==============================] - 27s 61ms/step - loss: 0.6563 - accuracy: 0.8067 - precision: 0.8521 - recall: 0.7611 - auc: 0.9716 - f1_score: 0.8036 - val_loss: 1.2951 - val_accuracy: 0.6126 - val_precision: 0.6688 - val_recall: 0.5559 - val_auc: 0.8976 - val_f1_score: 0.6071
# Epoch 33/100
# 449/449 [==============================] - 29s 64ms/step - loss: 0.6302 - accuracy: 0.8134 - precision: 0.8570 - recall: 0.7714 - auc: 0.9735 - f1_score: 0.8117 - val_loss: 1.2584 - val_accuracy: 0.6397 - val_precision: 0.6831 - val_recall: 0.6038 - val_auc: 0.9071 - val_f1_score: 0.6427
# Epoch 34/100
# 449/449 [==============================] - 31s 69ms/step - loss: 0.6041 - accuracy: 0.8235 - precision: 0.8633 - recall: 0.7843 - auc: 0.9753 - f1_score: 0.8215 - val_loss: 1.3085 - val_accuracy: 0.6356 - val_precision: 0.6729 - val_recall: 0.6032 - val_auc: 0.9045 - val_f1_score: 0.6365
# Epoch 35/100
# 449/449 [==============================] - 27s 61ms/step - loss: 0.5856 - accuracy: 0.8262 - precision: 0.8648 - recall: 0.7877 - auc: 0.9768 - f1_score: 0.8242 - val_loss: 1.3231 - val_accuracy: 0.6337 - val_precision: 0.6755 - val_recall: 0.6049 - val_auc: 0.9024 - val_f1_score: 0.6392
# Epoch 36/100
# 449/449 [==============================] - 31s 70ms/step - loss: 0.5620 - accuracy: 0.8324 - precision: 0.8692 - recall: 0.7970 - auc: 0.9782 - f1_score: 0.8315 - val_loss: 1.3307 - val_accuracy: 0.6336 - val_precision: 0.6664 - val_recall: 0.6028 - val_auc: 0.9010 - val_f1_score: 0.6311
# Epoch 37/100
# 449/449 [==============================] - 30s 67ms/step - loss: 0.5341 - accuracy: 0.8419 - precision: 0.8780 - recall: 0.8114 - auc: 0.9802 - f1_score: 0.8431 - val_loss: 1.2815 - val_accuracy: 0.6407 - val_precision: 0.6759 - val_recall: 0.6078 - val_auc: 0.9056 - val_f1_score: 0.6381
# Epoch 38/100
# 449/449 [==============================] - 29s 64ms/step - loss: 0.5100 - accuracy: 0.8495 - precision: 0.8818 - recall: 0.8196 - auc: 0.9818 - f1_score: 0.8494 - val_loss: 1.3140 - val_accuracy: 0.6251 - val_precision: 0.6656 - val_recall: 0.5883 - val_auc: 0.9005 - val_f1_score: 0.6212
# Epoch 39/100
# 449/449 [==============================] - 30s 67ms/step - loss: 0.4990 - accuracy: 0.8527 - precision: 0.8806 - recall: 0.8226 - auc: 0.9823 - f1_score: 0.8504 - val_loss: 1.3011 - val_accuracy: 0.6473 - val_precision: 0.6757 - val_recall: 0.6239 - val_auc: 0.9070 - val_f1_score: 0.6460
# Epoch 40/100
# 449/449 [==============================] - 32s 72ms/step - loss: 0.4809 - accuracy: 0.8591 - precision: 0.8850 - recall: 0.8327 - auc: 0.9835 - f1_score: 0.8579 - val_loss: 1.3115 - val_accuracy: 0.6432 - val_precision: 0.6751 - val_recall: 0.6163 - val_auc: 0.9049 - val_f1_score: 0.6448
# Epoch 41/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.4629 - accuracy: 0.8625 - precision: 0.8889 - recall: 0.8378 - auc: 0.9845 - f1_score: 0.8625 - val_loss: 1.3419 - val_accuracy: 0.6344 - val_precision: 0.6635 - val_recall: 0.6098 - val_auc: 0.8993 - val_f1_score: 0.6339
# Epoch 42/100
# 449/449 [==============================] - 30s 66ms/step - loss: 0.4466 - accuracy: 0.8685 - precision: 0.8924 - recall: 0.8472 - auc: 0.9853 - f1_score: 0.8691 - val_loss: 1.3155 - val_accuracy: 0.6368 - val_precision: 0.6673 - val_recall: 0.6074 - val_auc: 0.9031 - val_f1_score: 0.6368
# Epoch 42: early stopping

# %%
model.save_weights('weights/weight3')

# %% [markdown]
# # 6. Evaluate Model

# %% [markdown]
# ## 6.1 Check some Score

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_dataset)
test_evaluation = model.evaluate(test_dataset)
# Out:
# 449/449 [==============================] - 20s 44ms/step - loss: 0.3750 - accuracy: 0.8900 - precision: 0.9139 - recall: 0.8685 - auc: 0.9908 - f1_score: 0.8904
# 113/113 [==============================] - 2s 18ms/step - loss: 1.3155 - accuracy: 0.6368 - precision: 0.6673 - recall: 0.6074 - auc: 0.9031 - f1_score: 0.6362

# %%
metric_list = ["Loss","accuracy", "Precision", "Recall", "Auc", "F1_Score"]

df = pd.DataFrame(list(zip(metric_list, 
                           [round(num, 3) for num in train_evalation], 
                           [round(num, 3) for num in test_evaluation])),
                  columns=['Metric Name', 'Train', 'Validate'])

print('\n\nModel Scores\n')

HTML(df.to_html(escape=False))
# Out:
# Model Scores
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Metric Name</th>
#       <th>Train</th>
#       <th>Validate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Loss</td>
#       <td>0.375</td>
#       <td>1.315</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>accuracy</td>
#       <td>0.890</td>
#       <td>0.637</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Precision</td>
#       <td>0.914</td>
#       <td>0.667</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Recall</td>
#       <td>0.868</td>
#       <td>0.607</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Auc</td>
#       <td>0.991</td>
#       <td>0.903</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>F1_Score</td>
#       <td>0.890</td>
#       <td>0.636</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 6.2 Visualize results

# %%
hs=history.history

acc = hs['accuracy']
val_acc = hs['val_accuracy']
loss =  hs['loss']
val_loss = hs['val_loss']
auc =  hs['auc']
val_auc = hs['val_auc']
precision =hs['precision']
val_precision =hs['val_precision']
f1 = hs['f1_score']
val_f1 = hs['val_f1_score']              

plt.style.use('Solarize_Light2')

fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

ax1.plot(range(1, len(acc) + 1), acc)
ax1.plot(range(1, len(val_acc) + 1), val_acc)
ax1.set_title('History of Accuracy')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.legend(['training', 'validation'])


ax2.plot(range(1, len(loss) + 1), loss)
ax2.plot(range(1, len(val_loss) + 1), val_loss)
ax2.set_title('History of Loss')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.legend(['training', 'validation'])

ax3.plot(range(1, len(auc) + 1), auc)
ax3.plot(range(1, len(val_auc) + 1), val_auc)
ax3.set_title('History of AUC')
ax3.set_xlabel('Epochs')
ax3.set_ylabel('AUC')
ax3.legend(['training', 'validation'])

ax4.plot(range(1, len(precision) + 1), precision)
ax4.plot(range(1, len(val_precision) + 1), val_precision)
ax4.set_title('History of Precision')
ax4.set_xlabel('Epochs')
ax4.set_ylabel('Precision')
ax4.legend(['training', 'validation'])

ax5.plot(range(1, len(f1) + 1), f1)
ax5.plot(range(1, len(val_f1) + 1), val_f1)
ax5.set_title('History of F1-score')
ax5.set_xlabel('Epochs')
ax5.set_ylabel('F1 score')
ax5.legend(['training', 'validation'])

plt.show()

# %% [markdown]
# ## 6.3 Confusion Matrix

# %%
y_true = test_dataset.classes
y_pred =  model.predict(test_dataset)
y_pred= tf.argmax(y_pred, axis = 1).numpy()

cm = confusion_matrix(y_true = y_true, y_pred = y_pred)
# Out:
# 113/113 [==============================] - 4s 18ms/step

# %%
plt.rcParams['figure.figsize'] = (14,7)

plt.style.use('seaborn-darkgrid')
plt.imshow(cm, interpolation='nearest', cmap='Reds')
plt.title('Confusion matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)    

print('Confusion matrix, without normalization\n')   
print(cm)

print("\n\n")
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j],
        horizontalalignment="center",
        color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# Confusion matrix, without normalization
#
# [[138   9 144 216 208 127 116]
#  [ 19   0  20  20  26  13  13]
#  [137  18 166 221 230 125 127]
#  [247  19 268 419 410 233 178]
#  [152  19 172 318 285 159 128]
#  [185  14 176 298 283 137 154]
#  [107  13 142 185 193 109  82]]

# %%
plt.style.use('seaborn')

cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(12,6))

im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=classes, yticklabels=classes,
       title = 'Normalized confusion matrix',
       ylabel='True label',
       xlabel='Predicted label')

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")


fmt = '.2f' 
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

fig.tight_layout()
plt.show()

# %% [markdown]
# # 7. Save Model

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# # 8. Test/Predict

# %%
plt.style.use('grayscale')
plt.grid(visible=None)
img_path='../input/fer2013/test/happy/PrivateTest_3333329.jpg'
test_image=image.load_img(img_path,target_size= IMAGE_SIZE,color_mode='grayscale')
test_image=image.img_to_array(test_image)
print(test_image.shape)
plt.imshow(test_image)
plt.show()
# Out:
# (48, 48, 1)

# %%
img=image.load_img(img_path,target_size=IMAGE_SIZE)
img = np.expand_dims(img, axis=0)
print(img.shape)
# Out:
# (1, 48, 48, 3)

# %%
result=model.predict(img)
print(result[0])
y_pred=np.argmax(result[0])
print('The person facial emotion is:',classes[y_pred])
# Out:
# [0. 0. 0. 1. 0. 0. 0.]
# The person facial emotion is: Happy

# %% [markdown]
# ### How to predict a single image with Keras ImageDataGenerator?
# https://stackoverflow.com/questions/63703280/how-to-predict-a-single-image-with-keras-imagedatagenerator

# %% [markdown]
# # Best model V23
