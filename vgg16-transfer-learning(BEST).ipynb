# %% [markdown]
# # 1. Import Libraries

# %%
import os
import keras
import itertools
import numpy as np
import pandas as pd
import seaborn as sn
from collections import Counter
import matplotlib.pyplot as plt

import tensorflow as tf
# from tensorflow.keras.preprocessing import image
# from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

# from tensorflow.keras.models import Model, Sequential
# from tensorflow.keras.applications import VGG16
# from tensorflow.keras.layers import Dense, Flatten, Dropout,BatchNormalization ,Activation, GlobalAveragePooling2D
# from tensorflow.keras.layers import GaussianNoise
# from tensorflow.keras import regularizers

import keras.backend as K
# from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
# from tensorflow.keras.callbacks import ReduceLROnPlateau,ModelCheckpoint,EarlyStopping

from IPython.display import Image, HTML
# from tensorflow.keras.utils import plot_model

# %% [markdown]
# # 2. Parameter

# %%
# declare path
train_dir = '../archive/train'
test_dir = '../archive/test'

# Image size

IMAGE_SIZE = (48,48)
IMAGE_SHAPE = IMAGE_SIZE + (3,)

BS = 64
EPOCHS = 100
ADAM_LEARNING_RATE = 0.0001
PATIENCE =10

classes=['Angry','Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %% [markdown]
# # 3. Prepare data

# %%
# Data augmentation

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
                                   featurewise_center=False,
                                   featurewise_std_normalization=False,
                                   rotation_range=10,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.1,
                                   horizontal_flip=True)

test_datagen  = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255)

# %%
# Load datasat

train_dataset  = train_datagen.flow_from_directory(directory = train_dir,
                                                   target_size = IMAGE_SIZE,
                                                   class_mode = 'categorical',
                                                   batch_size = BS)

test_dataset = test_datagen.flow_from_directory(directory = test_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  shuffle =True,
                                                  batch_size = BS)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # 4. Explore data

# %%
# Data labels

class_labels = test_dataset.class_indices
class_labels
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
# See the shape of any data

train_sample=next(train_dataset)
print(train_sample[0].shape)
# Out:
# (64, 48, 48, 3)

# %%
# Plot image of each class

plt.figure(figsize=(14,22))
i = 1
for expression in os.listdir(train_dir):
    print(train_dir + "/" + expression + '/' + os.listdir(train_dir +"/"+ expression)[1])
    img = tf.keras.preprocessing.image.load_img((train_dir + "/" + expression + '/' + os.listdir(train_dir +"/"+ expression)[1]))
    plt.subplot(1,7,i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()
# Out:
# ../archive/train/angry/Training_10120469.jpg
# ../archive/train/disgust/Training_10598340.jpg
# ../archive/train/fear/Training_10031494.jpg
# ../archive/train/happy/Training_10046809.jpg
# ../archive/train/neutral/Training_10031781.jpg
# ../archive/train/sad/Training_10031481.jpg
# ../archive/train/surprise/Training_1002457.jpg

# %% [markdown]
# # 5. Model

# %%
# VGG16

base_model = tf.keras.applications.VGG16(input_shape= IMAGE_SHAPE,include_top=False,weights="imagenet")
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 48, 48, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 48, 48, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 24, 24, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 24, 24, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 24, 24, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 12, 12, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 12, 12, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 6, 6, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 6, 6, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Freezing Layers

# for layer in base_model.layers[:11]:
#     layer.trainable=False

# %%
# Build transfer learning Model

model=tf.keras.models.Sequential()
model.add(base_model)
# model.add(tf.keras.layers.BatchNormalization())
# model.add(tf.keras.layers.GlobalAveragePooling2D())
# ,bias_regularizer=tf.keras.regularizers.l2()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(256, activation='relu',kernel_regularizer=tf.keras.regularizers.l2(),))
# model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.3))

model.add(tf.keras.layers.Dense(128, activation='relu',kernel_regularizer=tf.keras.regularizers.l2(),))
# model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.3))

model.add(tf.keras.layers.Dense(7, activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 1, 1, 512)         14714688
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 14,879,815
# Trainable params: 14,879,815
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, to_file='model.jpg')

# %%
# Model trainable

print("Model trainable",len(model.trainable_variables))
# Out:
# Model trainable 32

# %%
# Compile model

def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

METRICS = [
      'accuracy',
    #   tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      f1_score,
]

adam = tf.keras.optimizers.Adam(learning_rate=ADAM_LEARNING_RATE, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

model.compile(optimizer=adam, loss='categorical_crossentropy',metrics=METRICS)

# %%
# Run Model

# counter = Counter(train_dataset.classes)                          
# max_val = float(max(counter.values()))       
# class_weights = {class_id : round(max_val/num_images,2) for class_id, num_images in counter.items()}  

# lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = PATIENCE,verbose = 1,factor = 0.50, min_lr = 1e-10)
# mcp = ModelCheckpoint('model.h5')
es = tf.keras.callbacks.EarlyStopping(verbose=1, patience=70)

history=model.fit(train_dataset,
                  validation_data=test_dataset,
                  epochs = EPOCHS,
                  verbose =1,
                  callbacks=[es])
# Out:
# Epoch 1/100
# 449/449 [==============================] - 31s 59ms/step - loss: 4.7907 - accuracy: 0.3900 - precision: 0.7333 - recall: 0.1560 - auc: 0.7724 - f1_score: 0.2439 - val_loss: 3.1559 - val_accuracy: 0.5318 - val_precision: 0.7715 - val_recall: 0.2997 - val_auc: 0.8707 - val_f1_score: 0.4294
# Epoch 2/100
# 449/449 [==============================] - 25s 56ms/step - loss: 2.6108 - accuracy: 0.5268 - precision: 0.7391 - recall: 0.3146 - auc: 0.8617 - f1_score: 0.4374 - val_loss: 2.0534 - val_accuracy: 0.5756 - val_precision: 0.7709 - val_recall: 0.3915 - val_auc: 0.8957 - val_f1_score: 0.5164
# Epoch 3/100
# 449/449 [==============================] - 25s 56ms/step - loss: 1.8947 - accuracy: 0.5726 - precision: 0.7405 - recall: 0.3871 - auc: 0.8870 - f1_score: 0.5061 - val_loss: 1.6599 - val_accuracy: 0.5960 - val_precision: 0.7462 - val_recall: 0.4465 - val_auc: 0.9035 - val_f1_score: 0.5569
# Epoch 4/100
# 449/449 [==============================] - 25s 57ms/step - loss: 1.5839 - accuracy: 0.5993 - precision: 0.7524 - recall: 0.4328 - auc: 0.9002 - f1_score: 0.5479 - val_loss: 1.4878 - val_accuracy: 0.5932 - val_precision: 0.7955 - val_recall: 0.4009 - val_auc: 0.9049 - val_f1_score: 0.5320
# Epoch 5/100
# 449/449 [==============================] - 25s 57ms/step - loss: 1.4006 - accuracy: 0.6214 - precision: 0.7560 - recall: 0.4679 - auc: 0.9095 - f1_score: 0.5766 - val_loss: 1.3507 - val_accuracy: 0.6160 - val_precision: 0.7322 - val_recall: 0.5077 - val_auc: 0.9102 - val_f1_score: 0.6004
# Epoch 6/100
# 449/449 [==============================] - 26s 57ms/step - loss: 1.2788 - accuracy: 0.6353 - precision: 0.7605 - recall: 0.4873 - auc: 0.9159 - f1_score: 0.5922 - val_loss: 1.2262 - val_accuracy: 0.6411 - val_precision: 0.7411 - val_recall: 0.5365 - val_auc: 0.9196 - val_f1_score: 0.6209
# Epoch 7/100
# 449/449 [==============================] - 26s 57ms/step - loss: 1.1721 - accuracy: 0.6519 - precision: 0.7664 - recall: 0.5234 - auc: 0.9235 - f1_score: 0.6206 - val_loss: 1.1571 - val_accuracy: 0.6424 - val_precision: 0.7464 - val_recall: 0.5458 - val_auc: 0.9227 - val_f1_score: 0.6283
# Epoch 8/100
# 449/449 [==============================] - 25s 57ms/step - loss: 1.0934 - accuracy: 0.6653 - precision: 0.7738 - recall: 0.5394 - auc: 0.9290 - f1_score: 0.6345 - val_loss: 1.1236 - val_accuracy: 0.6488 - val_precision: 0.7341 - val_recall: 0.5532 - val_auc: 0.9226 - val_f1_score: 0.6306
# Epoch 9/100
# 449/449 [==============================] - 26s 58ms/step - loss: 1.0271 - accuracy: 0.6780 - precision: 0.7768 - recall: 0.5649 - auc: 0.9342 - f1_score: 0.6534 - val_loss: 1.0940 - val_accuracy: 0.6478 - val_precision: 0.7399 - val_recall: 0.5613 - val_auc: 0.9225 - val_f1_score: 0.6367
# Epoch 10/100
# 449/449 [==============================] - 26s 59ms/step - loss: 0.9606 - accuracy: 0.6961 - precision: 0.7872 - recall: 0.5907 - auc: 0.9403 - f1_score: 0.6737 - val_loss: 1.0677 - val_accuracy: 0.6519 - val_precision: 0.7391 - val_recall: 0.5495 - val_auc: 0.9232 - val_f1_score: 0.6266
# Epoch 11/100
# 449/449 [==============================] - 26s 58ms/step - loss: 0.9179 - accuracy: 0.7057 - precision: 0.7944 - recall: 0.6075 - auc: 0.9434 - f1_score: 0.6878 - val_loss: 1.0309 - val_accuracy: 0.6597 - val_precision: 0.7417 - val_recall: 0.5908 - val_auc: 0.9276 - val_f1_score: 0.6565
# Epoch 12/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.8622 - accuracy: 0.7202 - precision: 0.8009 - recall: 0.6324 - auc: 0.9488 - f1_score: 0.7058 - val_loss: 1.0219 - val_accuracy: 0.6584 - val_precision: 0.7453 - val_recall: 0.5804 - val_auc: 0.9273 - val_f1_score: 0.6507
# Epoch 13/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.8174 - accuracy: 0.7334 - precision: 0.8101 - recall: 0.6515 - auc: 0.9529 - f1_score: 0.7215 - val_loss: 1.0124 - val_accuracy: 0.6666 - val_precision: 0.7346 - val_recall: 0.6039 - val_auc: 0.9284 - val_f1_score: 0.6616
# Epoch 14/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.7776 - accuracy: 0.7466 - precision: 0.8181 - recall: 0.6716 - auc: 0.9566 - f1_score: 0.7370 - val_loss: 1.0335 - val_accuracy: 0.6587 - val_precision: 0.7285 - val_recall: 0.6010 - val_auc: 0.9252 - val_f1_score: 0.6588
# Epoch 15/100
# 449/449 [==============================] - 26s 58ms/step - loss: 0.7341 - accuracy: 0.7596 - precision: 0.8214 - recall: 0.6907 - auc: 0.9607 - f1_score: 0.7497 - val_loss: 1.0084 - val_accuracy: 0.6694 - val_precision: 0.7317 - val_recall: 0.6205 - val_auc: 0.9288 - val_f1_score: 0.6717
# Epoch 16/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.7033 - accuracy: 0.7683 - precision: 0.8284 - recall: 0.7049 - auc: 0.9633 - f1_score: 0.7612 - val_loss: 1.0134 - val_accuracy: 0.6608 - val_precision: 0.7297 - val_recall: 0.6032 - val_auc: 0.9265 - val_f1_score: 0.6603
# Epoch 17/100
# 449/449 [==============================] - 28s 61ms/step - loss: 0.6606 - accuracy: 0.7829 - precision: 0.8379 - recall: 0.7267 - auc: 0.9671 - f1_score: 0.7778 - val_loss: 1.0472 - val_accuracy: 0.6688 - val_precision: 0.7177 - val_recall: 0.6209 - val_auc: 0.9249 - val_f1_score: 0.6643
# Epoch 18/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.6253 - accuracy: 0.7951 - precision: 0.8440 - recall: 0.7420 - auc: 0.9701 - f1_score: 0.7891 - val_loss: 1.0482 - val_accuracy: 0.6760 - val_precision: 0.7164 - val_recall: 0.6360 - val_auc: 0.9256 - val_f1_score: 0.6723
# Epoch 19/100
# 449/449 [==============================] - 26s 58ms/step - loss: 0.5981 - accuracy: 0.8044 - precision: 0.8507 - recall: 0.7559 - auc: 0.9723 - f1_score: 0.8000 - val_loss: 1.0587 - val_accuracy: 0.6643 - val_precision: 0.7112 - val_recall: 0.6206 - val_auc: 0.9227 - val_f1_score: 0.6619
# Epoch 20/100
# 449/449 [==============================] - 26s 58ms/step - loss: 0.5622 - accuracy: 0.8157 - precision: 0.8583 - recall: 0.7724 - auc: 0.9754 - f1_score: 0.8126 - val_loss: 1.0876 - val_accuracy: 0.6662 - val_precision: 0.7066 - val_recall: 0.6333 - val_auc: 0.9225 - val_f1_score: 0.6676
# Epoch 21/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.5326 - accuracy: 0.8274 - precision: 0.8664 - recall: 0.7892 - auc: 0.9774 - f1_score: 0.8257 - val_loss: 1.0938 - val_accuracy: 0.6698 - val_precision: 0.7059 - val_recall: 0.6389 - val_auc: 0.9232 - val_f1_score: 0.6708
# Epoch 22/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.5162 - accuracy: 0.8324 - precision: 0.8696 - recall: 0.7964 - auc: 0.9786 - f1_score: 0.8311 - val_loss: 1.1336 - val_accuracy: 0.6680 - val_precision: 0.7051 - val_recall: 0.6369 - val_auc: 0.9181 - val_f1_score: 0.6695
# Epoch 23/100
# 449/449 [==============================] - 26s 59ms/step - loss: 0.4808 - accuracy: 0.8404 - precision: 0.8741 - recall: 0.8086 - auc: 0.9813 - f1_score: 0.8398 - val_loss: 1.2213 - val_accuracy: 0.6643 - val_precision: 0.6914 - val_recall: 0.6411 - val_auc: 0.9121 - val_f1_score: 0.6650
# Epoch 24/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.4660 - accuracy: 0.8491 - precision: 0.8810 - recall: 0.8182 - auc: 0.9823 - f1_score: 0.8482 - val_loss: 1.1496 - val_accuracy: 0.6609 - val_precision: 0.7009 - val_recall: 0.6278 - val_auc: 0.9154 - val_f1_score: 0.6620
# Epoch 25/100
# 449/449 [==============================] - 29s 64ms/step - loss: 0.4349 - accuracy: 0.8583 - precision: 0.8874 - recall: 0.8308 - auc: 0.9842 - f1_score: 0.8579 - val_loss: 1.1156 - val_accuracy: 0.6702 - val_precision: 0.7086 - val_recall: 0.6375 - val_auc: 0.9200 - val_f1_score: 0.6717
# Epoch 26/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.4164 - accuracy: 0.8667 - precision: 0.8941 - recall: 0.8422 - auc: 0.9855 - f1_score: 0.8671 - val_loss: 1.2666 - val_accuracy: 0.6626 - val_precision: 0.6870 - val_recall: 0.6420 - val_auc: 0.9078 - val_f1_score: 0.6642
# Epoch 27/100
# 449/449 [==============================] - 26s 59ms/step - loss: 0.4001 - accuracy: 0.8732 - precision: 0.8972 - recall: 0.8492 - auc: 0.9862 - f1_score: 0.8723 - val_loss: 1.1503 - val_accuracy: 0.6669 - val_precision: 0.7003 - val_recall: 0.6397 - val_auc: 0.9182 - val_f1_score: 0.6695
# Epoch 28/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.3781 - accuracy: 0.8788 - precision: 0.9020 - recall: 0.8565 - auc: 0.9877 - f1_score: 0.8784 - val_loss: 1.1964 - val_accuracy: 0.6668 - val_precision: 0.6963 - val_recall: 0.6466 - val_auc: 0.9146 - val_f1_score: 0.6711
# Epoch 29/100
# 449/449 [==============================] - 26s 58ms/step - loss: 0.3608 - accuracy: 0.8835 - precision: 0.9040 - recall: 0.8643 - auc: 0.9889 - f1_score: 0.8836 - val_loss: 1.2550 - val_accuracy: 0.6716 - val_precision: 0.6929 - val_recall: 0.6566 - val_auc: 0.9137 - val_f1_score: 0.6714
# Epoch 30/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.3518 - accuracy: 0.8865 - precision: 0.9065 - recall: 0.8671 - auc: 0.9891 - f1_score: 0.8863 - val_loss: 1.3940 - val_accuracy: 0.6654 - val_precision: 0.6853 - val_recall: 0.6514 - val_auc: 0.9028 - val_f1_score: 0.6688
# Epoch 31/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.3321 - accuracy: 0.8937 - precision: 0.9117 - recall: 0.8753 - auc: 0.9903 - f1_score: 0.8930 - val_loss: 1.2431 - val_accuracy: 0.6728 - val_precision: 0.6971 - val_recall: 0.6555 - val_auc: 0.9138 - val_f1_score: 0.6745
# Epoch 32/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.3159 - accuracy: 0.8993 - precision: 0.9163 - recall: 0.8837 - auc: 0.9909 - f1_score: 0.8995 - val_loss: 1.2997 - val_accuracy: 0.6775 - val_precision: 0.6985 - val_recall: 0.6620 - val_auc: 0.9123 - val_f1_score: 0.6813
# Epoch 33/100
# 449/449 [==============================] - 26s 59ms/step - loss: 0.3033 - accuracy: 0.9037 - precision: 0.9201 - recall: 0.8898 - auc: 0.9914 - f1_score: 0.9046 - val_loss: 1.3591 - val_accuracy: 0.6732 - val_precision: 0.6925 - val_recall: 0.6578 - val_auc: 0.9074 - val_f1_score: 0.6745
# Epoch 34/100
# 449/449 [==============================] - 28s 63ms/step - loss: 0.2953 - accuracy: 0.9052 - precision: 0.9201 - recall: 0.8907 - auc: 0.9920 - f1_score: 0.9050 - val_loss: 1.4135 - val_accuracy: 0.6711 - val_precision: 0.6894 - val_recall: 0.6578 - val_auc: 0.9043 - val_f1_score: 0.6733
# Epoch 35/100
# 449/449 [==============================] - 26s 59ms/step - loss: 0.2845 - accuracy: 0.9092 - precision: 0.9249 - recall: 0.8966 - auc: 0.9922 - f1_score: 0.9104 - val_loss: 1.3177 - val_accuracy: 0.6772 - val_precision: 0.6943 - val_recall: 0.6605 - val_auc: 0.9105 - val_f1_score: 0.6756
# Epoch 36/100
# 449/449 [==============================] - 27s 61ms/step - loss: 0.2657 - accuracy: 0.9164 - precision: 0.9283 - recall: 0.9039 - auc: 0.9935 - f1_score: 0.9158 - val_loss: 1.2966 - val_accuracy: 0.6602 - val_precision: 0.6840 - val_recall: 0.6396 - val_auc: 0.9075 - val_f1_score: 0.6618
# Epoch 37/100
# 449/449 [==============================] - 27s 61ms/step - loss: 0.2674 - accuracy: 0.9154 - precision: 0.9278 - recall: 0.9033 - auc: 0.9930 - f1_score: 0.9153 - val_loss: 1.4069 - val_accuracy: 0.6736 - val_precision: 0.6900 - val_recall: 0.6616 - val_auc: 0.9039 - val_f1_score: 0.6758
# Epoch 38/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.2616 - accuracy: 0.9170 - precision: 0.9285 - recall: 0.9061 - auc: 0.9935 - f1_score: 0.9170 - val_loss: 1.5432 - val_accuracy: 0.6686 - val_precision: 0.6806 - val_recall: 0.6585 - val_auc: 0.8983 - val_f1_score: 0.6703
# Epoch 39/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.2503 - accuracy: 0.9203 - precision: 0.9318 - recall: 0.9098 - auc: 0.9939 - f1_score: 0.9205 - val_loss: 1.4046 - val_accuracy: 0.6647 - val_precision: 0.6830 - val_recall: 0.6524 - val_auc: 0.9053 - val_f1_score: 0.6682
# Epoch 40/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.2412 - accuracy: 0.9243 - precision: 0.9349 - recall: 0.9148 - auc: 0.9941 - f1_score: 0.9247 - val_loss: 1.2764 - val_accuracy: 0.6846 - val_precision: 0.7030 - val_recall: 0.6680 - val_auc: 0.9129 - val_f1_score: 0.6858
# Epoch 41/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.2277 - accuracy: 0.9277 - precision: 0.9372 - recall: 0.9184 - auc: 0.9947 - f1_score: 0.9276 - val_loss: 1.4498 - val_accuracy: 0.6847 - val_precision: 0.6984 - val_recall: 0.6747 - val_auc: 0.9054 - val_f1_score: 0.6864
# Epoch 42/100
# 449/449 [==============================] - 27s 61ms/step - loss: 0.2265 - accuracy: 0.9279 - precision: 0.9366 - recall: 0.9192 - auc: 0.9946 - f1_score: 0.9278 - val_loss: 1.3781 - val_accuracy: 0.6663 - val_precision: 0.6865 - val_recall: 0.6534 - val_auc: 0.9035 - val_f1_score: 0.6704
# Epoch 43/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.2269 - accuracy: 0.9269 - precision: 0.9362 - recall: 0.9184 - auc: 0.9949 - f1_score: 0.9272 - val_loss: 1.5529 - val_accuracy: 0.6619 - val_precision: 0.6777 - val_recall: 0.6514 - val_auc: 0.8948 - val_f1_score: 0.6638
# Epoch 44/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.2208 - accuracy: 0.9322 - precision: 0.9405 - recall: 0.9238 - auc: 0.9947 - f1_score: 0.9320 - val_loss: 1.5261 - val_accuracy: 0.6754 - val_precision: 0.6882 - val_recall: 0.6640 - val_auc: 0.8973 - val_f1_score: 0.6757
# Epoch 45/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.2204 - accuracy: 0.9303 - precision: 0.9383 - recall: 0.9225 - auc: 0.9949 - f1_score: 0.9302 - val_loss: 1.5405 - val_accuracy: 0.6695 - val_precision: 0.6820 - val_recall: 0.6606 - val_auc: 0.8975 - val_f1_score: 0.6720
# Epoch 46/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.2012 - accuracy: 0.9358 - precision: 0.9431 - recall: 0.9286 - auc: 0.9957 - f1_score: 0.9358 - val_loss: 1.3761 - val_accuracy: 0.6669 - val_precision: 0.6858 - val_recall: 0.6509 - val_auc: 0.9057 - val_f1_score: 0.6687
# Epoch 47/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.1945 - accuracy: 0.9398 - precision: 0.9465 - recall: 0.9338 - auc: 0.9957 - f1_score: 0.9401 - val_loss: 1.5938 - val_accuracy: 0.6790 - val_precision: 0.6886 - val_recall: 0.6697 - val_auc: 0.8938 - val_f1_score: 0.6792
# Epoch 48/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.1929 - accuracy: 0.9401 - precision: 0.9473 - recall: 0.9336 - auc: 0.9960 - f1_score: 0.9403 - val_loss: 1.5244 - val_accuracy: 0.6771 - val_precision: 0.6873 - val_recall: 0.6691 - val_auc: 0.8997 - val_f1_score: 0.6780
# Epoch 49/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.1878 - accuracy: 0.9395 - precision: 0.9464 - recall: 0.9334 - auc: 0.9961 - f1_score: 0.9398 - val_loss: 1.7026 - val_accuracy: 0.6739 - val_precision: 0.6848 - val_recall: 0.6656 - val_auc: 0.8894 - val_f1_score: 0.6752
# Epoch 50/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.1911 - accuracy: 0.9393 - precision: 0.9465 - recall: 0.9321 - auc: 0.9961 - f1_score: 0.9392 - val_loss: 1.5045 - val_accuracy: 0.6665 - val_precision: 0.6807 - val_recall: 0.6541 - val_auc: 0.8982 - val_f1_score: 0.6681
# Epoch 51/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.1842 - accuracy: 0.9425 - precision: 0.9486 - recall: 0.9370 - auc: 0.9962 - f1_score: 0.9427 - val_loss: 1.6275 - val_accuracy: 0.6665 - val_precision: 0.6767 - val_recall: 0.6583 - val_auc: 0.8937 - val_f1_score: 0.6675
# Epoch 52/100
# 449/449 [==============================] - 28s 61ms/step - loss: 0.1837 - accuracy: 0.9416 - precision: 0.9479 - recall: 0.9355 - auc: 0.9961 - f1_score: 0.9416 - val_loss: 1.5786 - val_accuracy: 0.6677 - val_precision: 0.6790 - val_recall: 0.6548 - val_auc: 0.8952 - val_f1_score: 0.6690
# Epoch 53/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.1767 - accuracy: 0.9442 - precision: 0.9510 - recall: 0.9388 - auc: 0.9964 - f1_score: 0.9448 - val_loss: 1.6715 - val_accuracy: 0.6682 - val_precision: 0.6780 - val_recall: 0.6616 - val_auc: 0.8918 - val_f1_score: 0.6700
# Epoch 54/100
# 449/449 [==============================] - 27s 61ms/step - loss: 0.1709 - accuracy: 0.9450 - precision: 0.9506 - recall: 0.9395 - auc: 0.9967 - f1_score: 0.9450 - val_loss: 1.5850 - val_accuracy: 0.6748 - val_precision: 0.6887 - val_recall: 0.6661 - val_auc: 0.8971 - val_f1_score: 0.6774
# Epoch 55/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.1715 - accuracy: 0.9459 - precision: 0.9516 - recall: 0.9400 - auc: 0.9966 - f1_score: 0.9457 - val_loss: 1.6532 - val_accuracy: 0.6707 - val_precision: 0.6792 - val_recall: 0.6605 - val_auc: 0.8923 - val_f1_score: 0.6710
# Epoch 56/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.1698 - accuracy: 0.9457 - precision: 0.9524 - recall: 0.9405 - auc: 0.9966 - f1_score: 0.9463 - val_loss: 1.5810 - val_accuracy: 0.6688 - val_precision: 0.6800 - val_recall: 0.6592 - val_auc: 0.8968 - val_f1_score: 0.6696
# Epoch 57/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.1675 - accuracy: 0.9475 - precision: 0.9530 - recall: 0.9427 - auc: 0.9967 - f1_score: 0.9477 - val_loss: 1.6347 - val_accuracy: 0.6767 - val_precision: 0.6877 - val_recall: 0.6682 - val_auc: 0.8920 - val_f1_score: 0.6780
# Epoch 58/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.1644 - accuracy: 0.9470 - precision: 0.9527 - recall: 0.9417 - auc: 0.9969 - f1_score: 0.9471 - val_loss: 1.6703 - val_accuracy: 0.6817 - val_precision: 0.6927 - val_recall: 0.6732 - val_auc: 0.8950 - val_f1_score: 0.6824
# Epoch 59/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.1538 - accuracy: 0.9515 - precision: 0.9565 - recall: 0.9465 - auc: 0.9972 - f1_score: 0.9514 - val_loss: 1.5555 - val_accuracy: 0.6840 - val_precision: 0.6954 - val_recall: 0.6747 - val_auc: 0.9002 - val_f1_score: 0.6871
# Epoch 60/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.1541 - accuracy: 0.9517 - precision: 0.9563 - recall: 0.9473 - auc: 0.9970 - f1_score: 0.9517 - val_loss: 1.7613 - val_accuracy: 0.6872 - val_precision: 0.6955 - val_recall: 0.6814 - val_auc: 0.8894 - val_f1_score: 0.6884
# Epoch 61/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.1545 - accuracy: 0.9520 - precision: 0.9568 - recall: 0.9470 - auc: 0.9972 - f1_score: 0.9518 - val_loss: 1.7454 - val_accuracy: 0.6804 - val_precision: 0.6890 - val_recall: 0.6726 - val_auc: 0.8889 - val_f1_score: 0.6794
# Epoch 62/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.1581 - accuracy: 0.9495 - precision: 0.9553 - recall: 0.9449 - auc: 0.9969 - f1_score: 0.9501 - val_loss: 1.6292 - val_accuracy: 0.6811 - val_precision: 0.6907 - val_recall: 0.6716 - val_auc: 0.8945 - val_f1_score: 0.6826
# Epoch 63/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.1487 - accuracy: 0.9518 - precision: 0.9568 - recall: 0.9474 - auc: 0.9974 - f1_score: 0.9521 - val_loss: 1.8054 - val_accuracy: 0.6773 - val_precision: 0.6852 - val_recall: 0.6700 - val_auc: 0.8871 - val_f1_score: 0.6784
# Epoch 64/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.1528 - accuracy: 0.9525 - precision: 0.9576 - recall: 0.9480 - auc: 0.9971 - f1_score: 0.9527 - val_loss: 1.7562 - val_accuracy: 0.6725 - val_precision: 0.6827 - val_recall: 0.6665 - val_auc: 0.8876 - val_f1_score: 0.6746
# Epoch 65/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.1474 - accuracy: 0.9511 - precision: 0.9563 - recall: 0.9470 - auc: 0.9974 - f1_score: 0.9516 - val_loss: 1.8195 - val_accuracy: 0.6737 - val_precision: 0.6823 - val_recall: 0.6683 - val_auc: 0.8862 - val_f1_score: 0.6753
# Epoch 66/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.1519 - accuracy: 0.9515 - precision: 0.9570 - recall: 0.9470 - auc: 0.9971 - f1_score: 0.9519 - val_loss: 1.8174 - val_accuracy: 0.6769 - val_precision: 0.6862 - val_recall: 0.6702 - val_auc: 0.8883 - val_f1_score: 0.6782
# Epoch 67/100
# 449/449 [==============================] - 28s 61ms/step - loss: 0.1491 - accuracy: 0.9535 - precision: 0.9584 - recall: 0.9486 - auc: 0.9972 - f1_score: 0.9534 - val_loss: 1.7128 - val_accuracy: 0.6695 - val_precision: 0.6812 - val_recall: 0.6602 - val_auc: 0.8909 - val_f1_score: 0.6722
# Epoch 68/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.1433 - accuracy: 0.9550 - precision: 0.9593 - recall: 0.9503 - auc: 0.9975 - f1_score: 0.9548 - val_loss: 1.8039 - val_accuracy: 0.6746 - val_precision: 0.6832 - val_recall: 0.6670 - val_auc: 0.8873 - val_f1_score: 0.6766
# Epoch 69/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.1390 - accuracy: 0.9560 - precision: 0.9608 - recall: 0.9519 - auc: 0.9975 - f1_score: 0.9562 - val_loss: 1.6516 - val_accuracy: 0.6829 - val_precision: 0.6929 - val_recall: 0.6744 - val_auc: 0.8940 - val_f1_score: 0.6829
# Epoch 70/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.1297 - accuracy: 0.9587 - precision: 0.9623 - recall: 0.9545 - auc: 0.9977 - f1_score: 0.9583 - val_loss: 1.7898 - val_accuracy: 0.6819 - val_precision: 0.6916 - val_recall: 0.6733 - val_auc: 0.8900 - val_f1_score: 0.6824
# Epoch 71/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.1366 - accuracy: 0.9566 - precision: 0.9613 - recall: 0.9528 - auc: 0.9975 - f1_score: 0.9570 - val_loss: 1.7895 - val_accuracy: 0.6833 - val_precision: 0.6891 - val_recall: 0.6744 - val_auc: 0.8913 - val_f1_score: 0.6818
# Epoch 72/100
# 449/449 [==============================] - 27s 61ms/step - loss: 0.1311 - accuracy: 0.9565 - precision: 0.9610 - recall: 0.9528 - auc: 0.9979 - f1_score: 0.9569 - val_loss: 1.8598 - val_accuracy: 0.6807 - val_precision: 0.6873 - val_recall: 0.6743 - val_auc: 0.8886 - val_f1_score: 0.6831
# Epoch 73/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.1380 - accuracy: 0.9570 - precision: 0.9611 - recall: 0.9522 - auc: 0.9975 - f1_score: 0.9566 - val_loss: 1.5451 - val_accuracy: 0.6796 - val_precision: 0.6910 - val_recall: 0.6694 - val_auc: 0.8992 - val_f1_score: 0.6796
# Epoch 74/100
# 449/449 [==============================] - 27s 61ms/step - loss: 0.1358 - accuracy: 0.9571 - precision: 0.9621 - recall: 0.9532 - auc: 0.9976 - f1_score: 0.9575 - val_loss: 1.6978 - val_accuracy: 0.6761 - val_precision: 0.6886 - val_recall: 0.6684 - val_auc: 0.8903 - val_f1_score: 0.6770
# Epoch 75/100
# 449/449 [==============================] - 27s 61ms/step - loss: 0.1280 - accuracy: 0.9583 - precision: 0.9623 - recall: 0.9544 - auc: 0.9979 - f1_score: 0.9583 - val_loss: 1.7370 - val_accuracy: 0.6824 - val_precision: 0.6925 - val_recall: 0.6765 - val_auc: 0.8882 - val_f1_score: 0.6863
# Epoch 76/100
# 449/449 [==============================] - 28s 61ms/step - loss: 0.1278 - accuracy: 0.9589 - precision: 0.9629 - recall: 0.9554 - auc: 0.9978 - f1_score: 0.9591 - val_loss: 1.8128 - val_accuracy: 0.6730 - val_precision: 0.6819 - val_recall: 0.6669 - val_auc: 0.8881 - val_f1_score: 0.6732
# Epoch 77/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.1265 - accuracy: 0.9602 - precision: 0.9643 - recall: 0.9564 - auc: 0.9978 - f1_score: 0.9603 - val_loss: 1.8201 - val_accuracy: 0.6794 - val_precision: 0.6883 - val_recall: 0.6728 - val_auc: 0.8899 - val_f1_score: 0.6813
# Epoch 78/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.1325 - accuracy: 0.9583 - precision: 0.9623 - recall: 0.9541 - auc: 0.9975 - f1_score: 0.9582 - val_loss: 1.7072 - val_accuracy: 0.6819 - val_precision: 0.6927 - val_recall: 0.6734 - val_auc: 0.8925 - val_f1_score: 0.6815
# Epoch 79/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.1298 - accuracy: 0.9597 - precision: 0.9638 - recall: 0.9556 - auc: 0.9976 - f1_score: 0.9596 - val_loss: 1.9926 - val_accuracy: 0.6686 - val_precision: 0.6742 - val_recall: 0.6630 - val_auc: 0.8807 - val_f1_score: 0.6687
# Epoch 80/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.1272 - accuracy: 0.9593 - precision: 0.9637 - recall: 0.9557 - auc: 0.9977 - f1_score: 0.9596 - val_loss: 1.8425 - val_accuracy: 0.6750 - val_precision: 0.6857 - val_recall: 0.6687 - val_auc: 0.8858 - val_f1_score: 0.6783
# Epoch 81/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.1214 - accuracy: 0.9607 - precision: 0.9646 - recall: 0.9571 - auc: 0.9980 - f1_score: 0.9608 - val_loss: 1.7398 - val_accuracy: 0.6811 - val_precision: 0.6917 - val_recall: 0.6739 - val_auc: 0.8916 - val_f1_score: 0.6815
# Epoch 82/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.1226 - accuracy: 0.9603 - precision: 0.9637 - recall: 0.9568 - auc: 0.9979 - f1_score: 0.9601 - val_loss: 1.8637 - val_accuracy: 0.6772 - val_precision: 0.6875 - val_recall: 0.6698 - val_auc: 0.8847 - val_f1_score: 0.6772
# Epoch 83/100
# 449/449 [==============================] - 26s 59ms/step - loss: 0.1219 - accuracy: 0.9605 - precision: 0.9643 - recall: 0.9566 - auc: 0.9978 - f1_score: 0.9604 - val_loss: 1.7777 - val_accuracy: 0.6797 - val_precision: 0.6898 - val_recall: 0.6733 - val_auc: 0.8916 - val_f1_score: 0.6823
# Epoch 84/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.1203 - accuracy: 0.9614 - precision: 0.9657 - recall: 0.9578 - auc: 0.9980 - f1_score: 0.9616 - val_loss: 1.8242 - val_accuracy: 0.6680 - val_precision: 0.6774 - val_recall: 0.6595 - val_auc: 0.8846 - val_f1_score: 0.6672
# Epoch 85/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.1127 - accuracy: 0.9641 - precision: 0.9676 - recall: 0.9608 - auc: 0.9983 - f1_score: 0.9641 - val_loss: 1.7619 - val_accuracy: 0.6801 - val_precision: 0.6888 - val_recall: 0.6714 - val_auc: 0.8895 - val_f1_score: 0.6786
# Epoch 85: early stopping

# %%
model.save_weights('../Project/weights/weight3')

# %% [markdown]
# # 6. Evaluate Model

# %% [markdown]
# ## 6.1 Check some Score

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_dataset)
test_evaluation = model.evaluate(test_dataset)
# Out:
# 449/449 [==============================] - 21s 46ms/step - loss: 0.0980 - accuracy: 0.9676 - precision: 0.9717 - recall: 0.9636 - auc: 0.9988 - f1_score: 0.9676
# 113/113 [==============================] - 2s 17ms/step - loss: 1.7619 - accuracy: 0.6801 - precision: 0.6888 - recall: 0.6714 - auc: 0.8895 - f1_score: 0.6816

# %%
metric_list = ["Loss","accuracy", "Precision", "Recall", "Auc", "F1_Score"]

df = pd.DataFrame(list(zip(metric_list, 
                           [round(num, 3) for num in train_evalation], 
                           [round(num, 3) for num in test_evaluation])),
                  columns=['Metric Name', 'Train', 'Validate'])

print('\n\nModel Scores\n')

HTML(df.to_html(escape=False))
# Out:
# Model Scores
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Metric Name</th>
#       <th>Train</th>
#       <th>Validate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Loss</td>
#       <td>0.098</td>
#       <td>1.762</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>accuracy</td>
#       <td>0.968</td>
#       <td>0.680</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Precision</td>
#       <td>0.972</td>
#       <td>0.689</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Recall</td>
#       <td>0.964</td>
#       <td>0.671</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Auc</td>
#       <td>0.999</td>
#       <td>0.890</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>F1_Score</td>
#       <td>0.968</td>
#       <td>0.682</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 6.2 Visualize results

# %%
hs=history.history

acc = hs['accuracy']
val_acc = hs['val_accuracy']
loss =  hs['loss']
val_loss = hs['val_loss']
auc =  hs['auc']
val_auc = hs['val_auc']
precision =hs['precision']
val_precision =hs['val_precision']
f1 = hs['f1_score']
val_f1 = hs['val_f1_score']              

# plt.style.use('Solarize_Light2')

fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

ax1.plot(range(1, len(acc) + 1), acc)
ax1.plot(range(1, len(val_acc) + 1), val_acc)
ax1.set_title('History of Accuracy')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.legend(['training', 'validation'])


ax2.plot(range(1, len(loss) + 1), loss)
ax2.plot(range(1, len(val_loss) + 1), val_loss)
ax2.set_title('History of Loss')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.legend(['training', 'validation'])

ax3.plot(range(1, len(auc) + 1), auc)
ax3.plot(range(1, len(val_auc) + 1), val_auc)
ax3.set_title('History of AUC')
ax3.set_xlabel('Epochs')
ax3.set_ylabel('AUC')
ax3.legend(['training', 'validation'])

ax4.plot(range(1, len(precision) + 1), precision)
ax4.plot(range(1, len(val_precision) + 1), val_precision)
ax4.set_title('History of Precision')
ax4.set_xlabel('Epochs')
ax4.set_ylabel('Precision')
ax4.legend(['training', 'validation'])

ax5.plot(range(1, len(f1) + 1), f1)
ax5.plot(range(1, len(val_f1) + 1), val_f1)
ax5.set_title('History of F1-score')
ax5.set_xlabel('Epochs')
ax5.set_ylabel('F1 score')
ax5.legend(['training', 'validation'])

plt.show()

# %% [markdown]
# ## 6.3 Confusion Matrix

# %%
y_true = test_dataset.classes
y_pred =  model.predict(test_dataset)
y_pred= tf.argmax(y_pred, axis = 1).numpy()

cm = confusion_matrix(y_true = y_true, y_pred = y_pred)
# Out:
# 113/113 [==============================] - 2s 18ms/step

# %%
plt.rcParams['figure.figsize'] = (14,7)

plt.style.use('seaborn-darkgrid')
plt.imshow(cm, interpolation='nearest', cmap='Reds')
plt.title('Confusion matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)    

print('Confusion matrix, without normalization\n')   
print(cm)

print("\n\n")
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j],
        horizontalalignment="center",
        color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# Confusion matrix, without normalization
#
# [[128  14 124 212 217 152 111]
#  [ 19   2  14  25  25  19   7]
#  [130  18 123 236 228 161 128]
#  [235  21 226 409 390 286 207]
#  [155  10 158 300 252 209 149]
#  [177  16 162 277 255 204 156]
#  [104  10 110 202 166 140  99]]

# %%
plt.style.use('seaborn')

cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(12,6))

im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=classes, yticklabels=classes,
       title = 'Normalized confusion matrix',
       ylabel='True label',
       xlabel='Predicted label')

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")


fmt = '.2f' 
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

fig.tight_layout()
plt.show()

# %% [markdown]
# # 7. Save Model

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# # 8. Test/Predict

# %%
plt.style.use('grayscale')
plt.grid(visible=None)
img_path='../input/fer2013/test/happy/PrivateTest_3333329.jpg'
test_image=image.load_img(img_path,target_size= IMAGE_SIZE,color_mode='grayscale')
test_image=image.img_to_array(test_image)
print(test_image.shape)
plt.imshow(test_image)
plt.show()
# Out:
# (48, 48, 1)

# %%
img=image.load_img(img_path,target_size=IMAGE_SIZE)
img = np.expand_dims(img, axis=0)
print(img.shape)
# Out:
# (1, 48, 48, 3)

# %%
result=model.predict(img)
print(result[0])
y_pred=np.argmax(result[0])
print('The person facial emotion is:',classes[y_pred])
# Out:
# [0. 0. 0. 1. 0. 0. 0.]
# The person facial emotion is: Happy

# %% [markdown]
# ### How to predict a single image with Keras ImageDataGenerator?
# https://stackoverflow.com/questions/63703280/how-to-predict-a-single-image-with-keras-imagedatagenerator

# %% [markdown]
# # Best model V23
