# %% [markdown]
# # 1. Import Libraries

# %%
import os
import keras
import itertools
import numpy as np
import pandas as pd
import seaborn as sn
from collections import Counter
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten, Dropout,BatchNormalization ,Activation, GlobalAveragePooling2D
from tensorflow.keras.layers import GaussianNoise
from tensorflow.keras import regularizers

import keras.backend as K
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.callbacks import ReduceLROnPlateau,ModelCheckpoint,EarlyStopping

from IPython.display import Image, HTML
from tensorflow.keras.utils import plot_model

# %% [markdown]
# # 2. Parameter

# %%
# declare path
train_dir = '../archive/train'
test_dir = '../archive/test'

# Image size

IMAGE_SIZE = (48,48)
IMAGE_SHAPE = IMAGE_SIZE + (3,)

BS = 64
EPOCHS = 100
ADAM_LEARNING_RATE = 0.0001
PATIENCE =10

classes=['Angry','Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %% [markdown]
# # 3. Prepare data

# %%
# Data augmentation

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
                                   featurewise_center=False,
                                   featurewise_std_normalization=False,
                                   rotation_range=10,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.1,
                                   horizontal_flip=True)

test_datagen  = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255)

# %%
# Load datasat

train_dataset  = train_datagen.flow_from_directory(directory = train_dir,
                                                   target_size = IMAGE_SIZE,
                                                   class_mode = 'categorical',
                                                   batch_size = BS)

test_dataset = test_datagen.flow_from_directory(directory = test_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  shuffle =True,
                                                  batch_size = BS)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # 4. Explore data

# %%
# Data labels

class_labels = test_dataset.class_indices
class_labels
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
# See the shape of any data

train_sample=next(train_dataset)
print(train_sample[0].shape)
# Out:
# (64, 48, 48, 3)

# %%
# Plot image of each class

plt.figure(figsize=(14,22))
i = 1
for expression in os.listdir(train_dir):
    print(train_dir + "/" + expression + '/' + os.listdir(train_dir +"/"+ expression)[1])
    img = load_img((train_dir + "/" + expression + '/' + os.listdir(train_dir +"/"+ expression)[1]))
    plt.subplot(1,7,i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()
# Out:
# ../archive/train/angry/Training_10120469.jpg
# ../archive/train/disgust/Training_10598340.jpg
# ../archive/train/fear/Training_10031494.jpg
# ../archive/train/happy/Training_10046809.jpg
# ../archive/train/neutral/Training_10031781.jpg
# ../archive/train/sad/Training_10031481.jpg
# ../archive/train/surprise/Training_1002457.jpg

# %% [markdown]
# # 5. Model

# %%
# VGG16

base_model = tf.keras.applications.VGG16(input_shape= IMAGE_SHAPE,include_top=False,weights="imagenet")
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 48, 48, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 48, 48, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 24, 24, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 24, 24, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 24, 24, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 12, 12, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 12, 12, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 6, 6, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 6, 6, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Freezing Layers

for layer in base_model.layers[:11]:
    layer.trainable=False

# %%
# Build transfer learning Model

model=tf.keras.models.Sequential()
model.add(base_model)
model.add(tf.keras.layers.BatchNormalization())
# model.add(tf.keras.layers.GaussianNoise(0.01))
model.add(tf.keras.layers.GlobalAveragePooling2D())

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(256, activation='relu',kernel_regularizer=tf.keras.regularizers.l2(),bias_regularizer=tf.keras.regularizers.l2()))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.5))

model.add(tf.keras.layers.Dense(128, activation='relu',kernel_regularizer=tf.keras.regularizers.l2(),bias_regularizer=tf.keras.regularizers.l2()))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.5))

model.add(tf.keras.layers.Dense(7, activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 1, 1, 512)         14714688
#
#  batch_normalization (BatchN  (None, 1, 1, 512)        2048
#  ormalization)
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 14,883,399
# Trainable params: 13,146,119
# Non-trainable params: 1,737,280
# _________________________________________________________________

# %%
# Model trainable

print("Model trainable",len(model.trainable_variables))
# Out:
# Model trainable 24

# %%
# Compile model

def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

METRICS = [
      'accuracy',
    #   tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      f1_score,
]

adam = tf.keras.optimizers.Adam(learning_rate=ADAM_LEARNING_RATE, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

model.compile(optimizer="adam", loss='categorical_crossentropy',metrics=METRICS)

# %%
# Run Model

# counter = Counter(train_dataset.classes)                          
# max_val = float(max(counter.values()))       
# class_weights = {class_id : round(max_val/num_images,2) for class_id, num_images in counter.items()}  

# lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = PATIENCE,verbose = 1,factor = 0.50, min_lr = 1e-10)
# mcp = ModelCheckpoint('model.h5')
es = tf.keras.callbacks.EarlyStopping(verbose=1, patience=50)

history=model.fit(train_dataset,
                  validation_data=test_dataset,
                  epochs = EPOCHS,
                  verbose =1,
                  callbacks=[es])
# Out:
# Epoch 1/100
# 449/449 [==============================] - 31s 60ms/step - loss: 4.1396 - accuracy: 0.2371 - precision: 0.2777 - recall: 0.0629 - auc: 0.6283 - f1_score: 0.1021 - val_loss: 2.5045 - val_accuracy: 0.3133 - val_precision: 0.8015 - val_recall: 0.0298 - val_auc: 0.7138 - val_f1_score: 0.0588
# Epoch 2/100
# 449/449 [==============================] - 26s 58ms/step - loss: 2.0962 - accuracy: 0.3389 - precision: 0.6074 - recall: 0.1012 - auc: 0.7391 - f1_score: 0.1685 - val_loss: 1.6732 - val_accuracy: 0.4207 - val_precision: 0.8111 - val_recall: 0.1693 - val_auc: 0.8030 - val_f1_score: 0.2772
# Epoch 3/100
# 449/449 [==============================] - 26s 57ms/step - loss: 1.5802 - accuracy: 0.4301 - precision: 0.7361 - recall: 0.2087 - auc: 0.8062 - f1_score: 0.3245 - val_loss: 1.5086 - val_accuracy: 0.4274 - val_precision: 0.8808 - val_recall: 0.1832 - val_auc: 0.8087 - val_f1_score: 0.2999
# Epoch 4/100
# 449/449 [==============================] - 26s 57ms/step - loss: 1.4631 - accuracy: 0.4536 - precision: 0.7585 - recall: 0.2291 - auc: 0.8221 - f1_score: 0.3505 - val_loss: 5.4456 - val_accuracy: 0.2267 - val_precision: 0.2204 - val_recall: 0.2091 - val_auc: 0.5020 - val_f1_score: 0.2153
# Epoch 5/100
# 449/449 [==============================] - 26s 58ms/step - loss: 1.4079 - accuracy: 0.4809 - precision: 0.7412 - recall: 0.2546 - auc: 0.8395 - f1_score: 0.3779 - val_loss: 1.3979 - val_accuracy: 0.4760 - val_precision: 0.6857 - val_recall: 0.2696 - val_auc: 0.8430 - val_f1_score: 0.3857
# Epoch 6/100
# 449/449 [==============================] - 26s 57ms/step - loss: 1.3711 - accuracy: 0.4979 - precision: 0.7440 - recall: 0.2744 - auc: 0.8505 - f1_score: 0.4000 - val_loss: 1.5122 - val_accuracy: 0.4468 - val_precision: 0.7007 - val_recall: 0.2345 - val_auc: 0.8159 - val_f1_score: 0.3505
# Epoch 7/100
# 449/449 [==============================] - 25s 56ms/step - loss: 1.3443 - accuracy: 0.5176 - precision: 0.7401 - recall: 0.2952 - auc: 0.8581 - f1_score: 0.4214 - val_loss: 1.4513 - val_accuracy: 0.4507 - val_precision: 0.7231 - val_recall: 0.2765 - val_auc: 0.8273 - val_f1_score: 0.3979
# Epoch 8/100
# 449/449 [==============================] - 24s 54ms/step - loss: 1.3187 - accuracy: 0.5289 - precision: 0.7407 - recall: 0.3115 - auc: 0.8644 - f1_score: 0.4370 - val_loss: 1.4937 - val_accuracy: 0.4861 - val_precision: 0.6436 - val_recall: 0.3431 - val_auc: 0.8373 - val_f1_score: 0.4450
# Epoch 9/100
# 449/449 [==============================] - 25s 55ms/step - loss: 1.3018 - accuracy: 0.5363 - precision: 0.7417 - recall: 0.3294 - auc: 0.8689 - f1_score: 0.4549 - val_loss: 1.5406 - val_accuracy: 0.4289 - val_precision: 0.7586 - val_recall: 0.2364 - val_auc: 0.8109 - val_f1_score: 0.3573
# Epoch 10/100
# 449/449 [==============================] - 24s 54ms/step - loss: 1.2892 - accuracy: 0.5405 - precision: 0.7458 - recall: 0.3346 - auc: 0.8718 - f1_score: 0.4610 - val_loss: 1.2976 - val_accuracy: 0.5361 - val_precision: 0.6493 - val_recall: 0.4280 - val_auc: 0.8739 - val_f1_score: 0.5160
# Epoch 11/100
# 449/449 [==============================] - 24s 54ms/step - loss: 1.2728 - accuracy: 0.5458 - precision: 0.7424 - recall: 0.3438 - auc: 0.8756 - f1_score: 0.4689 - val_loss: 1.3092 - val_accuracy: 0.5199 - val_precision: 0.6964 - val_recall: 0.4040 - val_auc: 0.8680 - val_f1_score: 0.5099
# Epoch 12/100
# 449/449 [==============================] - 25s 55ms/step - loss: 1.2591 - accuracy: 0.5561 - precision: 0.7477 - recall: 0.3578 - auc: 0.8789 - f1_score: 0.4832 - val_loss: 1.2700 - val_accuracy: 0.5460 - val_precision: 0.7601 - val_recall: 0.3607 - val_auc: 0.8749 - val_f1_score: 0.4878
# Epoch 13/100
# 449/449 [==============================] - 25s 55ms/step - loss: 1.2456 - accuracy: 0.5641 - precision: 0.7433 - recall: 0.3680 - auc: 0.8821 - f1_score: 0.4911 - val_loss: 1.3444 - val_accuracy: 0.5273 - val_precision: 0.6302 - val_recall: 0.4147 - val_auc: 0.8676 - val_f1_score: 0.4986
# Epoch 14/100
# 449/449 [==============================] - 25s 55ms/step - loss: 1.2407 - accuracy: 0.5638 - precision: 0.7441 - recall: 0.3750 - auc: 0.8833 - f1_score: 0.4977 - val_loss: 1.2510 - val_accuracy: 0.5607 - val_precision: 0.7499 - val_recall: 0.3683 - val_auc: 0.8807 - val_f1_score: 0.4908
# Epoch 15/100
# 449/449 [==============================] - 25s 56ms/step - loss: 1.2202 - accuracy: 0.5783 - precision: 0.7450 - recall: 0.3921 - auc: 0.8874 - f1_score: 0.5130 - val_loss: 1.2598 - val_accuracy: 0.5532 - val_precision: 0.6590 - val_recall: 0.4489 - val_auc: 0.8832 - val_f1_score: 0.5328
# Epoch 16/100
# 449/449 [==============================] - 25s 56ms/step - loss: 1.2077 - accuracy: 0.5803 - precision: 0.7509 - recall: 0.3980 - auc: 0.8899 - f1_score: 0.5191 - val_loss: 1.2412 - val_accuracy: 0.5567 - val_precision: 0.7429 - val_recall: 0.3888 - val_auc: 0.8846 - val_f1_score: 0.5075
# Epoch 17/100
# 449/449 [==============================] - 25s 55ms/step - loss: 1.1954 - accuracy: 0.5899 - precision: 0.7460 - recall: 0.4132 - auc: 0.8929 - f1_score: 0.5310 - val_loss: 1.3467 - val_accuracy: 0.5319 - val_precision: 0.6866 - val_recall: 0.3944 - val_auc: 0.8638 - val_f1_score: 0.5000
# Epoch 18/100
# 449/449 [==============================] - 25s 56ms/step - loss: 1.1822 - accuracy: 0.5934 - precision: 0.7486 - recall: 0.4272 - auc: 0.8962 - f1_score: 0.5430 - val_loss: 1.2103 - val_accuracy: 0.5738 - val_precision: 0.7308 - val_recall: 0.4259 - val_auc: 0.8907 - val_f1_score: 0.5377
# Epoch 19/100
# 449/449 [==============================] - 25s 56ms/step - loss: 1.1733 - accuracy: 0.6038 - precision: 0.7476 - recall: 0.4345 - auc: 0.8982 - f1_score: 0.5486 - val_loss: 1.2098 - val_accuracy: 0.5741 - val_precision: 0.7358 - val_recall: 0.4249 - val_auc: 0.8899 - val_f1_score: 0.5386
# Epoch 20/100
# 449/449 [==============================] - 25s 56ms/step - loss: 1.1517 - accuracy: 0.6080 - precision: 0.7478 - recall: 0.4472 - auc: 0.9022 - f1_score: 0.5587 - val_loss: 1.1743 - val_accuracy: 0.5957 - val_precision: 0.7661 - val_recall: 0.4152 - val_auc: 0.8971 - val_f1_score: 0.5374
# Epoch 21/100
# 449/449 [==============================] - 25s 56ms/step - loss: 1.1381 - accuracy: 0.6119 - precision: 0.7501 - recall: 0.4561 - auc: 0.9049 - f1_score: 0.5665 - val_loss: 1.2376 - val_accuracy: 0.5705 - val_precision: 0.7032 - val_recall: 0.4390 - val_auc: 0.8869 - val_f1_score: 0.5397
# Epoch 22/100
# 449/449 [==============================] - 25s 56ms/step - loss: 1.1342 - accuracy: 0.6169 - precision: 0.7509 - recall: 0.4643 - auc: 0.9064 - f1_score: 0.5728 - val_loss: 1.2250 - val_accuracy: 0.5734 - val_precision: 0.6794 - val_recall: 0.4278 - val_auc: 0.8895 - val_f1_score: 0.5253
# Epoch 23/100
# 449/449 [==============================] - 25s 56ms/step - loss: 1.1152 - accuracy: 0.6237 - precision: 0.7567 - recall: 0.4747 - auc: 0.9090 - f1_score: 0.5822 - val_loss: 1.1446 - val_accuracy: 0.6032 - val_precision: 0.7242 - val_recall: 0.4788 - val_auc: 0.9041 - val_f1_score: 0.5764
# Epoch 24/100
# 449/449 [==============================] - 25s 55ms/step - loss: 1.1125 - accuracy: 0.6270 - precision: 0.7553 - recall: 0.4749 - auc: 0.9098 - f1_score: 0.5821 - val_loss: 1.1729 - val_accuracy: 0.6002 - val_precision: 0.7052 - val_recall: 0.4840 - val_auc: 0.9009 - val_f1_score: 0.5734
# Epoch 25/100
# 449/449 [==============================] - 25s 56ms/step - loss: 1.0868 - accuracy: 0.6372 - precision: 0.7609 - recall: 0.4971 - auc: 0.9138 - f1_score: 0.6003 - val_loss: 4.2948 - val_accuracy: 0.3651 - val_precision: 0.3809 - val_recall: 0.2579 - val_auc: 0.6805 - val_f1_score: 0.3072
# Epoch 26/100
# 449/449 [==============================] - 25s 56ms/step - loss: 1.0894 - accuracy: 0.6367 - precision: 0.7580 - recall: 0.4979 - auc: 0.9139 - f1_score: 0.6001 - val_loss: 1.1379 - val_accuracy: 0.6115 - val_precision: 0.7529 - val_recall: 0.4670 - val_auc: 0.9043 - val_f1_score: 0.5749
# Epoch 27/100
# 449/449 [==============================] - 25s 56ms/step - loss: 1.0694 - accuracy: 0.6424 - precision: 0.7594 - recall: 0.5085 - auc: 0.9168 - f1_score: 0.6085 - val_loss: 1.1489 - val_accuracy: 0.6069 - val_precision: 0.7500 - val_recall: 0.4673 - val_auc: 0.9023 - val_f1_score: 0.5727
# Epoch 28/100
# 449/449 [==============================] - 27s 60ms/step - loss: 1.0601 - accuracy: 0.6446 - precision: 0.7632 - recall: 0.5141 - auc: 0.9184 - f1_score: 0.6138 - val_loss: 1.1410 - val_accuracy: 0.6096 - val_precision: 0.7243 - val_recall: 0.4992 - val_auc: 0.9048 - val_f1_score: 0.5914
# Epoch 29/100
# 449/449 [==============================] - 27s 60ms/step - loss: 1.0432 - accuracy: 0.6535 - precision: 0.7678 - recall: 0.5250 - auc: 0.9208 - f1_score: 0.6228 - val_loss: 1.1628 - val_accuracy: 0.6000 - val_precision: 0.7083 - val_recall: 0.4926 - val_auc: 0.9009 - val_f1_score: 0.5798
# Epoch 30/100
# 449/449 [==============================] - 27s 59ms/step - loss: 1.0294 - accuracy: 0.6565 - precision: 0.7691 - recall: 0.5297 - auc: 0.9231 - f1_score: 0.6263 - val_loss: 1.1258 - val_accuracy: 0.6162 - val_precision: 0.7330 - val_recall: 0.5010 - val_auc: 0.9080 - val_f1_score: 0.5945
# Epoch 31/100
# 449/449 [==============================] - 27s 60ms/step - loss: 1.0174 - accuracy: 0.6642 - precision: 0.7705 - recall: 0.5468 - auc: 0.9253 - f1_score: 0.6387 - val_loss: 1.1473 - val_accuracy: 0.6173 - val_precision: 0.7319 - val_recall: 0.5104 - val_auc: 0.9032 - val_f1_score: 0.6014
# Epoch 32/100
# 449/449 [==============================] - 27s 60ms/step - loss: 1.0072 - accuracy: 0.6678 - precision: 0.7731 - recall: 0.5489 - auc: 0.9269 - f1_score: 0.6410 - val_loss: 1.1099 - val_accuracy: 0.6293 - val_precision: 0.7274 - val_recall: 0.5337 - val_auc: 0.9107 - val_f1_score: 0.6156
# Epoch 33/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.9863 - accuracy: 0.6772 - precision: 0.7777 - recall: 0.5612 - auc: 0.9298 - f1_score: 0.6514 - val_loss: 1.1546 - val_accuracy: 0.6237 - val_precision: 0.7452 - val_recall: 0.4845 - val_auc: 0.9040 - val_f1_score: 0.5875
# Epoch 34/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.9784 - accuracy: 0.6800 - precision: 0.7787 - recall: 0.5649 - auc: 0.9312 - f1_score: 0.6538 - val_loss: 1.2033 - val_accuracy: 0.5947 - val_precision: 0.6874 - val_recall: 0.4841 - val_auc: 0.8941 - val_f1_score: 0.5656
# Epoch 35/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.9628 - accuracy: 0.6847 - precision: 0.7845 - recall: 0.5765 - auc: 0.9333 - f1_score: 0.6637 - val_loss: 1.1517 - val_accuracy: 0.6165 - val_precision: 0.7007 - val_recall: 0.5245 - val_auc: 0.9058 - val_f1_score: 0.5997
# Epoch 36/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.9509 - accuracy: 0.6888 - precision: 0.7824 - recall: 0.5838 - auc: 0.9351 - f1_score: 0.6681 - val_loss: 1.1962 - val_accuracy: 0.6002 - val_precision: 0.7324 - val_recall: 0.4663 - val_auc: 0.8954 - val_f1_score: 0.5703
# Epoch 37/100
# 449/449 [==============================] - 27s 61ms/step - loss: 0.9464 - accuracy: 0.6945 - precision: 0.7857 - recall: 0.5872 - auc: 0.9362 - f1_score: 0.6714 - val_loss: 1.1547 - val_accuracy: 0.6134 - val_precision: 0.6987 - val_recall: 0.5205 - val_auc: 0.9063 - val_f1_score: 0.5961
# Epoch 38/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.9282 - accuracy: 0.6971 - precision: 0.7885 - recall: 0.5973 - auc: 0.9385 - f1_score: 0.6789 - val_loss: 1.1475 - val_accuracy: 0.6219 - val_precision: 0.7011 - val_recall: 0.5414 - val_auc: 0.9075 - val_f1_score: 0.6120
# Epoch 39/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.9138 - accuracy: 0.7043 - precision: 0.7914 - recall: 0.6106 - auc: 0.9403 - f1_score: 0.6886 - val_loss: 1.1347 - val_accuracy: 0.6264 - val_precision: 0.7096 - val_recall: 0.5400 - val_auc: 0.9107 - val_f1_score: 0.6150
# Epoch 40/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.8911 - accuracy: 0.7177 - precision: 0.8000 - recall: 0.6261 - auc: 0.9434 - f1_score: 0.7019 - val_loss: 1.1526 - val_accuracy: 0.6162 - val_precision: 0.7132 - val_recall: 0.5189 - val_auc: 0.9041 - val_f1_score: 0.6002
# Epoch 41/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.8820 - accuracy: 0.7192 - precision: 0.7987 - recall: 0.6271 - auc: 0.9448 - f1_score: 0.7020 - val_loss: 1.1553 - val_accuracy: 0.6204 - val_precision: 0.7095 - val_recall: 0.5301 - val_auc: 0.9061 - val_f1_score: 0.6065
# Epoch 42/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.8712 - accuracy: 0.7220 - precision: 0.7995 - recall: 0.6355 - auc: 0.9461 - f1_score: 0.7074 - val_loss: 1.1958 - val_accuracy: 0.6158 - val_precision: 0.6906 - val_recall: 0.5414 - val_auc: 0.8987 - val_f1_score: 0.6060
# Epoch 43/100
# 449/449 [==============================] - 45s 100ms/step - loss: 1.0876 - accuracy: 0.6428 - precision: 0.7806 - recall: 0.5125 - auc: 0.9182 - f1_score: 0.5994 - val_loss: 1.4608 - val_accuracy: 0.5125 - val_precision: 0.5965 - val_recall: 0.4139 - val_auc: 0.8588 - val_f1_score: 0.4871
# Epoch 44/100
# 449/449 [==============================] - 44s 98ms/step - loss: 1.1266 - accuracy: 0.6200 - precision: 0.7563 - recall: 0.4629 - auc: 0.9085 - f1_score: 0.5724 - val_loss: 1.1681 - val_accuracy: 0.6016 - val_precision: 0.7424 - val_recall: 0.4480 - val_auc: 0.8994 - val_f1_score: 0.5584
# Epoch 45/100
# 449/449 [==============================] - 35s 77ms/step - loss: 0.9877 - accuracy: 0.6767 - precision: 0.7792 - recall: 0.5579 - auc: 0.9302 - f1_score: 0.6495 - val_loss: 1.1487 - val_accuracy: 0.6261 - val_precision: 0.7036 - val_recall: 0.5437 - val_auc: 0.9082 - val_f1_score: 0.6142
# Epoch 46/100
# 449/449 [==============================] - 30s 66ms/step - loss: 0.9318 - accuracy: 0.7005 - precision: 0.7895 - recall: 0.6000 - auc: 0.9380 - f1_score: 0.6810 - val_loss: 1.1810 - val_accuracy: 0.6094 - val_precision: 0.7027 - val_recall: 0.5071 - val_auc: 0.9011 - val_f1_score: 0.5882
# Epoch 47/100
# 449/449 [==============================] - 32s 72ms/step - loss: 0.8877 - accuracy: 0.7140 - precision: 0.8015 - recall: 0.6250 - auc: 0.9441 - f1_score: 0.7018 - val_loss: 1.1335 - val_accuracy: 0.6317 - val_precision: 0.7262 - val_recall: 0.5396 - val_auc: 0.9092 - val_f1_score: 0.6176
# Epoch 48/100
# 449/449 [==============================] - 37s 83ms/step - loss: 0.8691 - accuracy: 0.7265 - precision: 0.8060 - recall: 0.6387 - auc: 0.9465 - f1_score: 0.7119 - val_loss: 1.1768 - val_accuracy: 0.6308 - val_precision: 0.6929 - val_recall: 0.5626 - val_auc: 0.9061 - val_f1_score: 0.6211
# Epoch 49/100
# 449/449 [==============================] - 30s 68ms/step - loss: 0.8551 - accuracy: 0.7322 - precision: 0.8068 - recall: 0.6450 - auc: 0.9482 - f1_score: 0.7162 - val_loss: 1.1876 - val_accuracy: 0.6215 - val_precision: 0.6916 - val_recall: 0.5542 - val_auc: 0.9042 - val_f1_score: 0.6144
# Epoch 50/100
# 449/449 [==============================] - 31s 70ms/step - loss: 0.8377 - accuracy: 0.7360 - precision: 0.8117 - recall: 0.6600 - auc: 0.9502 - f1_score: 0.7275 - val_loss: 1.1830 - val_accuracy: 0.6287 - val_precision: 0.7007 - val_recall: 0.5609 - val_auc: 0.9066 - val_f1_score: 0.6226
# Epoch 51/100
# 449/449 [==============================] - 36s 80ms/step - loss: 0.8109 - accuracy: 0.7477 - precision: 0.8152 - recall: 0.6710 - auc: 0.9531 - f1_score: 0.7356 - val_loss: 1.1616 - val_accuracy: 0.6312 - val_precision: 0.7072 - val_recall: 0.5632 - val_auc: 0.9089 - val_f1_score: 0.6278
# Epoch 52/100
# 449/449 [==============================] - 32s 71ms/step - loss: 0.7904 - accuracy: 0.7538 - precision: 0.8192 - recall: 0.6828 - auc: 0.9558 - f1_score: 0.7444 - val_loss: 1.2394 - val_accuracy: 0.6191 - val_precision: 0.6733 - val_recall: 0.5665 - val_auc: 0.9035 - val_f1_score: 0.6149
# Epoch 53/100
# 449/449 [==============================] - 27s 61ms/step - loss: 0.7850 - accuracy: 0.7571 - precision: 0.8196 - recall: 0.6877 - auc: 0.9562 - f1_score: 0.7473 - val_loss: 1.2422 - val_accuracy: 0.6259 - val_precision: 0.6729 - val_recall: 0.5800 - val_auc: 0.9037 - val_f1_score: 0.6218
# Epoch 54/100
# 449/449 [==============================] - 27s 61ms/step - loss: 0.7698 - accuracy: 0.7650 - precision: 0.8239 - recall: 0.6978 - auc: 0.9580 - f1_score: 0.7552 - val_loss: 1.2521 - val_accuracy: 0.6148 - val_precision: 0.6862 - val_recall: 0.5496 - val_auc: 0.8974 - val_f1_score: 0.6096
# Epoch 55/100
# 449/449 [==============================] - 27s 61ms/step - loss: 0.7597 - accuracy: 0.7642 - precision: 0.8275 - recall: 0.6994 - auc: 0.9593 - f1_score: 0.7575 - val_loss: 1.2707 - val_accuracy: 0.6233 - val_precision: 0.6791 - val_recall: 0.5719 - val_auc: 0.9012 - val_f1_score: 0.6215
# Epoch 56/100
# 449/449 [==============================] - 29s 65ms/step - loss: 0.7468 - accuracy: 0.7700 - precision: 0.8272 - recall: 0.7037 - auc: 0.9606 - f1_score: 0.7601 - val_loss: 1.2613 - val_accuracy: 0.6252 - val_precision: 0.6821 - val_recall: 0.5759 - val_auc: 0.9013 - val_f1_score: 0.6262
# Epoch 57/100
# 449/449 [==============================] - 27s 61ms/step - loss: 0.7340 - accuracy: 0.7710 - precision: 0.8297 - recall: 0.7131 - auc: 0.9619 - f1_score: 0.7666 - val_loss: 1.1583 - val_accuracy: 0.6382 - val_precision: 0.7080 - val_recall: 0.5761 - val_auc: 0.9098 - val_f1_score: 0.6338
# Epoch 58/100
# 449/449 [==============================] - 25s 55ms/step - loss: 0.7126 - accuracy: 0.7822 - precision: 0.8392 - recall: 0.7228 - auc: 0.9636 - f1_score: 0.7763 - val_loss: 1.2186 - val_accuracy: 0.6308 - val_precision: 0.6944 - val_recall: 0.5765 - val_auc: 0.9064 - val_f1_score: 0.6298
# Epoch 59/100
# 449/449 [==============================] - 25s 56ms/step - loss: 0.7094 - accuracy: 0.7847 - precision: 0.8414 - recall: 0.7262 - auc: 0.9640 - f1_score: 0.7792 - val_loss: 1.2523 - val_accuracy: 0.6273 - val_precision: 0.6788 - val_recall: 0.5848 - val_auc: 0.9023 - val_f1_score: 0.6274
# Epoch 60/100
# 449/449 [==============================] - 26s 58ms/step - loss: 0.6949 - accuracy: 0.7899 - precision: 0.8412 - recall: 0.7357 - auc: 0.9657 - f1_score: 0.7846 - val_loss: 1.2606 - val_accuracy: 0.6349 - val_precision: 0.6850 - val_recall: 0.5935 - val_auc: 0.9058 - val_f1_score: 0.6351
# Epoch 61/100
# 449/449 [==============================] - 26s 57ms/step - loss: 0.6894 - accuracy: 0.7905 - precision: 0.8415 - recall: 0.7376 - auc: 0.9662 - f1_score: 0.7859 - val_loss: 1.2405 - val_accuracy: 0.6335 - val_precision: 0.6781 - val_recall: 0.5974 - val_auc: 0.9066 - val_f1_score: 0.6360
# Epoch 62/100
# 449/449 [==============================] - 26s 58ms/step - loss: 0.6758 - accuracy: 0.7949 - precision: 0.8459 - recall: 0.7449 - auc: 0.9676 - f1_score: 0.7920 - val_loss: 1.4076 - val_accuracy: 0.6094 - val_precision: 0.6446 - val_recall: 0.5723 - val_auc: 0.8876 - val_f1_score: 0.6074
# Epoch 63/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.6594 - accuracy: 0.7994 - precision: 0.8491 - recall: 0.7515 - auc: 0.9693 - f1_score: 0.7969 - val_loss: 1.2567 - val_accuracy: 0.6381 - val_precision: 0.6843 - val_recall: 0.5933 - val_auc: 0.9016 - val_f1_score: 0.6362
# Epoch 64/100
# 449/449 [==============================] - 26s 57ms/step - loss: 0.6470 - accuracy: 0.8046 - precision: 0.8509 - recall: 0.7603 - auc: 0.9702 - f1_score: 0.8026 - val_loss: 1.3147 - val_accuracy: 0.6317 - val_precision: 0.6757 - val_recall: 0.5887 - val_auc: 0.8961 - val_f1_score: 0.6282
# Epoch 65/100
# 449/449 [==============================] - 26s 59ms/step - loss: 0.6399 - accuracy: 0.8088 - precision: 0.8547 - recall: 0.7608 - auc: 0.9709 - f1_score: 0.8047 - val_loss: 1.2763 - val_accuracy: 0.6342 - val_precision: 0.6699 - val_recall: 0.5960 - val_auc: 0.9063 - val_f1_score: 0.6301
# Epoch 66/100
# 449/449 [==============================] - 26s 58ms/step - loss: 0.6372 - accuracy: 0.8099 - precision: 0.8566 - recall: 0.7622 - auc: 0.9711 - f1_score: 0.8063 - val_loss: 1.2503 - val_accuracy: 0.6346 - val_precision: 0.6901 - val_recall: 0.5843 - val_auc: 0.9041 - val_f1_score: 0.6327
# Epoch 67/100
# 449/449 [==============================] - 28s 63ms/step - loss: 0.6150 - accuracy: 0.8192 - precision: 0.8611 - recall: 0.7745 - auc: 0.9728 - f1_score: 0.8154 - val_loss: 1.3110 - val_accuracy: 0.6333 - val_precision: 0.6760 - val_recall: 0.5981 - val_auc: 0.9023 - val_f1_score: 0.6328
# Epoch 68/100
# 449/449 [==============================] - 33s 74ms/step - loss: 0.6045 - accuracy: 0.8216 - precision: 0.8631 - recall: 0.7790 - auc: 0.9738 - f1_score: 0.8187 - val_loss: 1.3233 - val_accuracy: 0.6333 - val_precision: 0.6717 - val_recall: 0.5992 - val_auc: 0.9025 - val_f1_score: 0.6336
# Epoch 69/100
# 449/449 [==============================] - 32s 71ms/step - loss: 0.6053 - accuracy: 0.8237 - precision: 0.8629 - recall: 0.7820 - auc: 0.9734 - f1_score: 0.8202 - val_loss: 1.3406 - val_accuracy: 0.6137 - val_precision: 0.6640 - val_recall: 0.5716 - val_auc: 0.8923 - val_f1_score: 0.6129
# Epoch 70/100
# 449/449 [==============================] - 32s 70ms/step - loss: 0.6094 - accuracy: 0.8196 - precision: 0.8608 - recall: 0.7786 - auc: 0.9734 - f1_score: 0.8171 - val_loss: 1.3036 - val_accuracy: 0.6326 - val_precision: 0.6719 - val_recall: 0.5972 - val_auc: 0.9015 - val_f1_score: 0.6329
# Epoch 71/100
# 449/449 [==============================] - 33s 73ms/step - loss: 0.5937 - accuracy: 0.8215 - precision: 0.8651 - recall: 0.7805 - auc: 0.9749 - f1_score: 0.8203 - val_loss: 1.3315 - val_accuracy: 0.6399 - val_precision: 0.6775 - val_recall: 0.6056 - val_auc: 0.9001 - val_f1_score: 0.6376
# Epoch 72/100
# 449/449 [==============================] - 36s 81ms/step - loss: 0.5704 - accuracy: 0.8336 - precision: 0.8702 - recall: 0.7961 - auc: 0.9764 - f1_score: 0.8312 - val_loss: 1.4030 - val_accuracy: 0.6350 - val_precision: 0.6704 - val_recall: 0.6041 - val_auc: 0.8960 - val_f1_score: 0.6336
# Epoch 73/100
# 449/449 [==============================] - 35s 79ms/step - loss: 0.5604 - accuracy: 0.8378 - precision: 0.8725 - recall: 0.8008 - auc: 0.9774 - f1_score: 0.8348 - val_loss: 1.3317 - val_accuracy: 0.6354 - val_precision: 0.6746 - val_recall: 0.6045 - val_auc: 0.9008 - val_f1_score: 0.6372
# Epoch 74/100
# 449/449 [==============================] - 32s 72ms/step - loss: 0.5547 - accuracy: 0.8406 - precision: 0.8741 - recall: 0.8029 - auc: 0.9776 - f1_score: 0.8367 - val_loss: 1.3300 - val_accuracy: 0.6305 - val_precision: 0.6750 - val_recall: 0.5938 - val_auc: 0.8972 - val_f1_score: 0.6312
# Epoch 75/100
# 449/449 [==============================] - 28s 62ms/step - loss: 0.5391 - accuracy: 0.8416 - precision: 0.8772 - recall: 0.8087 - auc: 0.9790 - f1_score: 0.8413 - val_loss: 1.3263 - val_accuracy: 0.6392 - val_precision: 0.6817 - val_recall: 0.6025 - val_auc: 0.9016 - val_f1_score: 0.6381
# Epoch 76/100
# 449/449 [==============================] - 27s 59ms/step - loss: 0.5293 - accuracy: 0.8460 - precision: 0.8783 - recall: 0.8130 - auc: 0.9799 - f1_score: 0.8441 - val_loss: 1.3945 - val_accuracy: 0.6220 - val_precision: 0.6607 - val_recall: 0.5928 - val_auc: 0.8961 - val_f1_score: 0.6245
# Epoch 77/100
# 449/449 [==============================] - 26s 58ms/step - loss: 0.5270 - accuracy: 0.8511 - precision: 0.8836 - recall: 0.8175 - auc: 0.9797 - f1_score: 0.8490 - val_loss: 1.4046 - val_accuracy: 0.6315 - val_precision: 0.6625 - val_recall: 0.6074 - val_auc: 0.8951 - val_f1_score: 0.6327
# Epoch 78/100
# 449/449 [==============================] - 26s 59ms/step - loss: 0.5265 - accuracy: 0.8467 - precision: 0.8811 - recall: 0.8153 - auc: 0.9798 - f1_score: 0.8467 - val_loss: 1.3453 - val_accuracy: 0.6335 - val_precision: 0.6779 - val_recall: 0.5984 - val_auc: 0.8964 - val_f1_score: 0.6338
# Epoch 79/100
# 449/449 [==============================] - 25s 57ms/step - loss: 0.5126 - accuracy: 0.8546 - precision: 0.8845 - recall: 0.8233 - auc: 0.9807 - f1_score: 0.8527 - val_loss: 1.3919 - val_accuracy: 0.6414 - val_precision: 0.6736 - val_recall: 0.6177 - val_auc: 0.8973 - val_f1_score: 0.6418
# Epoch 80/100
# 449/449 [==============================] - 25s 56ms/step - loss: 0.5050 - accuracy: 0.8543 - precision: 0.8843 - recall: 0.8249 - auc: 0.9815 - f1_score: 0.8534 - val_loss: 1.4417 - val_accuracy: 0.6202 - val_precision: 0.6531 - val_recall: 0.5919 - val_auc: 0.8901 - val_f1_score: 0.6222
# Epoch 81/100
# 449/449 [==============================] - 25s 55ms/step - loss: 0.4971 - accuracy: 0.8584 - precision: 0.8870 - recall: 0.8294 - auc: 0.9819 - f1_score: 0.8571 - val_loss: 1.3615 - val_accuracy: 0.6454 - val_precision: 0.6787 - val_recall: 0.6209 - val_auc: 0.9022 - val_f1_score: 0.6494
# Epoch 82/100
# 449/449 [==============================] - 25s 56ms/step - loss: 0.4852 - accuracy: 0.8631 - precision: 0.8904 - recall: 0.8354 - auc: 0.9826 - f1_score: 0.8617 - val_loss: 1.4098 - val_accuracy: 0.6357 - val_precision: 0.6718 - val_recall: 0.6071 - val_auc: 0.8974 - val_f1_score: 0.6383
# Epoch 82: early stopping

# %%
model.save_weights('../Project/weights/weight3')

# %% [markdown]
# # 6. Evaluate Model

# %% [markdown]
# ## 6.1 Check some Score

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_dataset)
test_evaluation = model.evaluate(test_dataset)
# Out:
# 449/449 [==============================] - 21s 46ms/step - loss: 0.4457 - accuracy: 0.8755 - precision: 0.9042 - recall: 0.8468 - auc: 0.9860 - f1_score: 0.8743
# 113/113 [==============================] - 2s 19ms/step - loss: 1.4098 - accuracy: 0.6357 - precision: 0.6718 - recall: 0.6071 - auc: 0.8974 - f1_score: 0.6382

# %%
metric_list = ["Loss","accuracy", "Precision", "Recall", "Auc", "F1_Score"]

df = pd.DataFrame(list(zip(metric_list, 
                           [round(num, 3) for num in train_evalation], 
                           [round(num, 3) for num in test_evaluation])),
                  columns=['Metric Name', 'Train', 'Validate'])

print('\n\nModel Scores\n')

HTML(df.to_html(escape=False))
# Out:
# Model Scores
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Metric Name</th>
#       <th>Train</th>
#       <th>Validate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Loss</td>
#       <td>0.446</td>
#       <td>1.410</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>accuracy</td>
#       <td>0.876</td>
#       <td>0.636</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Precision</td>
#       <td>0.904</td>
#       <td>0.672</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Recall</td>
#       <td>0.847</td>
#       <td>0.607</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Auc</td>
#       <td>0.986</td>
#       <td>0.897</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>F1_Score</td>
#       <td>0.874</td>
#       <td>0.638</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 6.2 Visualize results

# %%
hs=history.history

acc = hs['accuracy']
val_acc = hs['val_accuracy']
loss =  hs['loss']
val_loss = hs['val_loss']
auc =  hs['auc']
val_auc = hs['val_auc']
precision =hs['precision']
val_precision =hs['val_precision']
f1 = hs['f1_score']
val_f1 = hs['val_f1_score']              

plt.style.use('Solarize_Light2')

fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

ax1.plot(range(1, len(acc) + 1), acc)
ax1.plot(range(1, len(val_acc) + 1), val_acc)
ax1.set_title('History of Accuracy')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.legend(['training', 'validation'])


ax2.plot(range(1, len(loss) + 1), loss)
ax2.plot(range(1, len(val_loss) + 1), val_loss)
ax2.set_title('History of Loss')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.legend(['training', 'validation'])

ax3.plot(range(1, len(auc) + 1), auc)
ax3.plot(range(1, len(val_auc) + 1), val_auc)
ax3.set_title('History of AUC')
ax3.set_xlabel('Epochs')
ax3.set_ylabel('AUC')
ax3.legend(['training', 'validation'])

ax4.plot(range(1, len(precision) + 1), precision)
ax4.plot(range(1, len(val_precision) + 1), val_precision)
ax4.set_title('History of Precision')
ax4.set_xlabel('Epochs')
ax4.set_ylabel('Precision')
ax4.legend(['training', 'validation'])

ax5.plot(range(1, len(f1) + 1), f1)
ax5.plot(range(1, len(val_f1) + 1), val_f1)
ax5.set_title('History of F1-score')
ax5.set_xlabel('Epochs')
ax5.set_ylabel('F1 score')
ax5.legend(['training', 'validation'])

plt.show()

# %% [markdown]
# ## 6.3 Confusion Matrix

# %%
y_true = test_dataset.classes
y_pred =  model.predict(test_dataset)
y_pred= tf.argmax(y_pred, axis = 1).numpy()

cm = confusion_matrix(y_true = y_true, y_pred = y_pred)
# Out:
# 113/113 [==============================] - 2s 20ms/step

# %%
plt.rcParams['figure.figsize'] = (14,7)

plt.style.use('seaborn-darkgrid')
plt.imshow(cm, interpolation='nearest', cmap='Reds')
plt.title('Confusion matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)    

print('Confusion matrix, without normalization\n')   
print(cm)

print("\n\n")
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j],
        horizontalalignment="center",
        color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# Confusion matrix, without normalization
#
# [[144  18 117 250 166 149 114]
#  [ 18   1  16  29  21  13  13]
#  [173   7 114 292 174 150 114]
#  [286  19 216 501 286 268 198]
#  [197  20 143 371 189 161 152]
#  [217  19 142 360 186 184 139]
#  [155  10  94 227 125 117 103]]

# %%
plt.style.use('seaborn')

cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(12,6))

im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=classes, yticklabels=classes,
       title = 'Normalized confusion matrix',
       ylabel='True label',
       xlabel='Predicted label')

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")


fmt = '.2f' 
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

fig.tight_layout()
plt.show()

# %% [markdown]
# # 7. Save Model

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# # 8. Test/Predict

# %%
plt.style.use('grayscale')
plt.grid(visible=None)
img_path='../input/fer2013/test/happy/PrivateTest_3333329.jpg'
test_image=image.load_img(img_path,target_size= IMAGE_SIZE,color_mode='grayscale')
test_image=image.img_to_array(test_image)
print(test_image.shape)
plt.imshow(test_image)
plt.show()
# Out:
# (48, 48, 1)

# %%
img=image.load_img(img_path,target_size=IMAGE_SIZE)
img = np.expand_dims(img, axis=0)
print(img.shape)
# Out:
# (1, 48, 48, 3)

# %%
result=model.predict(img)
print(result[0])
y_pred=np.argmax(result[0])
print('The person facial emotion is:',classes[y_pred])
# Out:
# [0. 0. 0. 1. 0. 0. 0.]
# The person facial emotion is: Happy

# %% [markdown]
# ### How to predict a single image with Keras ImageDataGenerator?
# https://stackoverflow.com/questions/63703280/how-to-predict-a-single-image-with-keras-imagedatagenerator

# %% [markdown]
# # Best model V23
