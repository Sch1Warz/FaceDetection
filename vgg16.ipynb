# %% [markdown]
# # 1. Import Libraries

# %%
import os
import keras
import itertools
import numpy as np
import pandas as pd
import seaborn as sn
from collections import Counter
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten, Dropout,BatchNormalization ,Activation, GlobalAveragePooling2D
from tensorflow.keras.layers import GaussianNoise
from tensorflow.keras import regularizers

import keras.backend as K
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.callbacks import ReduceLROnPlateau,ModelCheckpoint,EarlyStopping

from IPython.display import Image, HTML
from tensorflow.keras.utils import plot_model

# %% [markdown]
# # 2. Parameter

# %%
# declare path
train_dir = '../archive/train'
test_dir = '../archive/test'

# Image size

IMAGE_SIZE = (48,48)
IMAGE_SHAPE = IMAGE_SIZE + (3,)

BS = 64
EPOCHS = 100
ADAM_LEARNING_RATE = 0.0001
PATIENCE =10

classes=['Angry','Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %% [markdown]
# # 3. Prepare data

# %%
# Data augmentation

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
                                   featurewise_center=False,
                                   featurewise_std_normalization=False,
                                   rotation_range=10,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.1,
                                   horizontal_flip=True)

test_datagen  = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255)

# %%
# Load datasat

train_dataset  = train_datagen.flow_from_directory(directory = train_dir,
                                                   target_size = IMAGE_SIZE,
                                                   class_mode = 'categorical',
                                                   batch_size = BS)

test_dataset = test_datagen.flow_from_directory(directory = test_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  shuffle =True,
                                                  batch_size = BS)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # 4. Explore data

# %%
# Data labels

class_labels = test_dataset.class_indices
class_labels
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
# See the shape of any data

train_sample=next(train_dataset)
print(train_sample[0].shape)
# Out:
# (64, 48, 48, 3)

# %%
# Plot image of each class

plt.figure(figsize=(14,22))
i = 1
for expression in os.listdir(train_dir):
    print(train_dir + "/" + expression + '/' + os.listdir(train_dir +"/"+ expression)[1])
    img = load_img((train_dir + "/" + expression + '/' + os.listdir(train_dir +"/"+ expression)[1]))
    plt.subplot(1,7,i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()
# Out:
# archive/train/angry/Training_10120469.jpg
# archive/train/disgust/Training_10598340.jpg
# archive/train/fear/Training_10031494.jpg
# archive/train/happy/Training_10046809.jpg
# archive/train/neutral/Training_10031781.jpg
# archive/train/sad/Training_10031481.jpg
# archive/train/surprise/Training_1002457.jpg

# %% [markdown]
# # 5. Model

# %%
# VGG16

base_model = tf.keras.applications.VGG16(input_shape= IMAGE_SHAPE,include_top=False,weights="imagenet")
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 48, 48, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 48, 48, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 24, 24, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 24, 24, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 24, 24, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 12, 12, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 12, 12, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 6, 6, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 6, 6, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Freezing Layers

for layer in base_model.layers[:11]:
    layer.trainable=False

# %%
# Build transfer learning Model

model=tf.keras.models.Sequential()
model.add(base_model)
# model.add(tf.keras.layers.BatchNormalization())
# model.add(tf.keras.layers.GaussianNoise(0.01))
# model.add(tf.keras.layers.GlobalAveragePooling2D())

model.add(tf.keras.layers.Flatten())
# model.add(tf.keras.layers.Dense(256, activation='relu',kernel_regularizer=tf.keras.regularizers.l2(0.001),bias_regularizer=tf.keras.regularizers.l2(0.001)))
# model.add(tf.keras.layers.BatchNormalization())
# model.add(tf.keras.layers.Dropout(0.5))

# model.add(tf.keras.layers.Dense(128, activation='relu',kernel_regularizer=tf.keras.regularizers.l2(0.001),bias_regularizer=tf.keras.regularizers.l2(0.001)))
# model.add(tf.keras.layers.BatchNormalization())
# model.add(tf.keras.layers.Dropout(0.5))

model.add(tf.keras.layers.Dense(7, activation="softmax"))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 1, 1, 512)         14714688
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_3 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 14,718,279
# Trainable params: 12,982,791
# Non-trainable params: 1,735,488
# _________________________________________________________________

# %%
# Model trainable

print("Model trainable",len(model.trainable_variables))
# Out:
# Model trainable 14

# %%
# Compile model

def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

METRICS = [
      'accuracy',
    #   tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      f1_score,
]

adam = tf.keras.optimizers.Adam(learning_rate=ADAM_LEARNING_RATE, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

model.compile(optimizer=adam, loss='categorical_crossentropy',metrics=METRICS)

# %%
# Run Model

# counter = Counter(train_dataset.classes)                          
# max_val = float(max(counter.values()))       
# class_weights = {class_id : round(max_val/num_images,2) for class_id, num_images in counter.items()}  

# lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = PATIENCE,verbose = 1,factor = 0.50, min_lr = 1e-10)
# mcp = ModelCheckpoint('model.h5')
es = tf.keras.callbacks.EarlyStopping(verbose=1, patience=18)

history=model.fit(train_dataset,
                  validation_data=test_dataset,
                  epochs = EPOCHS,
                  verbose =1,
                  callbacks=[es])
# Out:
# Epoch 1/100
# 449/449 [==============================] - 39s 73ms/step - loss: 1.4550 - accuracy: 0.4413 - precision: 0.6853 - recall: 0.2039 - auc: 0.8104 - f1_score: 0.3007 - val_loss: 1.2200 - val_accuracy: 0.5344 - val_precision: 0.7259 - val_recall: 0.3431 - val_auc: 0.8727 - val_f1_score: 0.4657
# Epoch 2/100
# 449/449 [==============================] - 35s 77ms/step - loss: 1.2231 - accuracy: 0.5394 - precision: 0.7239 - recall: 0.3372 - auc: 0.8719 - f1_score: 0.4579 - val_loss: 1.1479 - val_accuracy: 0.5653 - val_precision: 0.7239 - val_recall: 0.4043 - val_auc: 0.8879 - val_f1_score: 0.5171
# Epoch 3/100
# 449/449 [==============================] - 28s 62ms/step - loss: 1.1445 - accuracy: 0.5656 - precision: 0.7361 - recall: 0.3830 - auc: 0.8886 - f1_score: 0.5017 - val_loss: 1.1181 - val_accuracy: 0.5704 - val_precision: 0.7229 - val_recall: 0.4195 - val_auc: 0.8941 - val_f1_score: 0.5292
# Epoch 4/100
# 449/449 [==============================] - 24s 53ms/step - loss: 1.0781 - accuracy: 0.5932 - precision: 0.7410 - recall: 0.4248 - auc: 0.9019 - f1_score: 0.5382 - val_loss: 1.0908 - val_accuracy: 0.5970 - val_precision: 0.7239 - val_recall: 0.4668 - val_auc: 0.9005 - val_f1_score: 0.5670
# Epoch 5/100
# 449/449 [==============================] - 43s 95ms/step - loss: 1.0250 - accuracy: 0.6151 - precision: 0.7481 - recall: 0.4645 - auc: 0.9115 - f1_score: 0.5717 - val_loss: 1.1625 - val_accuracy: 0.5646 - val_precision: 0.7107 - val_recall: 0.3947 - val_auc: 0.8858 - val_f1_score: 0.5083
# Epoch 6/100
# 449/449 [==============================] - 29s 64ms/step - loss: 0.9779 - accuracy: 0.6321 - precision: 0.7578 - recall: 0.4971 - auc: 0.9197 - f1_score: 0.5988 - val_loss: 1.0442 - val_accuracy: 0.6169 - val_precision: 0.7162 - val_recall: 0.5100 - val_auc: 0.9096 - val_f1_score: 0.5945
# Epoch 7/100
# 449/449 [==============================] - 26s 59ms/step - loss: 0.9225 - accuracy: 0.6545 - precision: 0.7647 - recall: 0.5316 - auc: 0.9286 - f1_score: 0.6259 - val_loss: 1.0375 - val_accuracy: 0.6145 - val_precision: 0.7210 - val_recall: 0.5098 - val_auc: 0.9115 - val_f1_score: 0.5948
# Epoch 8/100
# 449/449 [==============================] - 26s 58ms/step - loss: 0.8744 - accuracy: 0.6777 - precision: 0.7761 - recall: 0.5658 - auc: 0.9358 - f1_score: 0.6533 - val_loss: 1.0677 - val_accuracy: 0.6120 - val_precision: 0.7070 - val_recall: 0.5166 - val_auc: 0.9067 - val_f1_score: 0.5972
# Epoch 9/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.8263 - accuracy: 0.6936 - precision: 0.7852 - recall: 0.5908 - auc: 0.9426 - f1_score: 0.6734 - val_loss: 1.0233 - val_accuracy: 0.6322 - val_precision: 0.7247 - val_recall: 0.5348 - val_auc: 0.9137 - val_f1_score: 0.6128
# Epoch 10/100
# 449/449 [==============================] - 27s 60ms/step - loss: 0.7807 - accuracy: 0.7119 - precision: 0.7971 - recall: 0.6208 - auc: 0.9486 - f1_score: 0.6972 - val_loss: 1.0321 - val_accuracy: 0.6330 - val_precision: 0.7312 - val_recall: 0.5415 - val_auc: 0.9139 - val_f1_score: 0.6227
# Epoch 11/100
# 449/449 [==============================] - 30s 66ms/step - loss: 0.7357 - accuracy: 0.7294 - precision: 0.8036 - recall: 0.6476 - auc: 0.9543 - f1_score: 0.7165 - val_loss: 1.0360 - val_accuracy: 0.6468 - val_precision: 0.7140 - val_recall: 0.5832 - val_auc: 0.9161 - val_f1_score: 0.6406
# Epoch 12/100
# 449/449 [==============================] - 34s 76ms/step - loss: 0.6938 - accuracy: 0.7438 - precision: 0.8111 - recall: 0.6738 - auc: 0.9592 - f1_score: 0.7355 - val_loss: 1.0527 - val_accuracy: 0.6399 - val_precision: 0.7177 - val_recall: 0.5600 - val_auc: 0.9133 - val_f1_score: 0.6285
# Epoch 13/100
# 449/449 [==============================] - 34s 77ms/step - loss: 0.6441 - accuracy: 0.7621 - precision: 0.8243 - recall: 0.6997 - auc: 0.9646 - f1_score: 0.7565 - val_loss: 1.1065 - val_accuracy: 0.6264 - val_precision: 0.6926 - val_recall: 0.5663 - val_auc: 0.9096 - val_f1_score: 0.6242
# Epoch 14/100
# 449/449 [==============================] - 35s 77ms/step - loss: 0.6029 - accuracy: 0.7792 - precision: 0.8338 - recall: 0.7229 - auc: 0.9687 - f1_score: 0.7740 - val_loss: 1.1328 - val_accuracy: 0.6414 - val_precision: 0.6850 - val_recall: 0.5943 - val_auc: 0.9107 - val_f1_score: 0.6384
# Epoch 15/100
# 449/449 [==============================] - 34s 76ms/step - loss: 0.5711 - accuracy: 0.7944 - precision: 0.8413 - recall: 0.7449 - auc: 0.9719 - f1_score: 0.7898 - val_loss: 1.1127 - val_accuracy: 0.6425 - val_precision: 0.7026 - val_recall: 0.5861 - val_auc: 0.9106 - val_f1_score: 0.6387
# Epoch 16/100
# 449/449 [==============================] - 34s 76ms/step - loss: 0.5349 - accuracy: 0.8051 - precision: 0.8505 - recall: 0.7609 - auc: 0.9750 - f1_score: 0.8028 - val_loss: 1.1746 - val_accuracy: 0.6439 - val_precision: 0.6842 - val_recall: 0.6082 - val_auc: 0.9093 - val_f1_score: 0.6434
# Epoch 17/100
# 449/449 [==============================] - 35s 78ms/step - loss: 0.4981 - accuracy: 0.8201 - precision: 0.8596 - recall: 0.7814 - auc: 0.9782 - f1_score: 0.8184 - val_loss: 1.1710 - val_accuracy: 0.6406 - val_precision: 0.6829 - val_recall: 0.5995 - val_auc: 0.9082 - val_f1_score: 0.6381
# Epoch 18/100
# 449/449 [==============================] - 35s 77ms/step - loss: 0.4665 - accuracy: 0.8302 - precision: 0.8664 - recall: 0.7945 - auc: 0.9809 - f1_score: 0.8287 - val_loss: 1.2346 - val_accuracy: 0.6413 - val_precision: 0.6782 - val_recall: 0.6046 - val_auc: 0.9071 - val_f1_score: 0.6371
# Epoch 19/100
# 449/449 [==============================] - 34s 75ms/step - loss: 0.4387 - accuracy: 0.8416 - precision: 0.8723 - recall: 0.8107 - auc: 0.9826 - f1_score: 0.8401 - val_loss: 1.2879 - val_accuracy: 0.6330 - val_precision: 0.6652 - val_recall: 0.6030 - val_auc: 0.9027 - val_f1_score: 0.6325
# Epoch 20/100
# 449/449 [==============================] - 32s 71ms/step - loss: 0.4154 - accuracy: 0.8490 - precision: 0.8788 - recall: 0.8215 - auc: 0.9843 - f1_score: 0.8489 - val_loss: 1.2494 - val_accuracy: 0.6413 - val_precision: 0.6777 - val_recall: 0.6095 - val_auc: 0.9040 - val_f1_score: 0.6429
# Epoch 21/100
# 449/449 [==============================] - 35s 77ms/step - loss: 0.3882 - accuracy: 0.8594 - precision: 0.8841 - recall: 0.8341 - auc: 0.9861 - f1_score: 0.8582 - val_loss: 1.3429 - val_accuracy: 0.6367 - val_precision: 0.6714 - val_recall: 0.6095 - val_auc: 0.8988 - val_f1_score: 0.6384
# Epoch 22/100
# 449/449 [==============================] - 34s 75ms/step - loss: 0.3734 - accuracy: 0.8662 - precision: 0.8908 - recall: 0.8451 - auc: 0.9870 - f1_score: 0.8672 - val_loss: 1.3950 - val_accuracy: 0.6439 - val_precision: 0.6671 - val_recall: 0.6212 - val_auc: 0.8991 - val_f1_score: 0.6425
# Epoch 23/100
# 449/449 [==============================] - 36s 81ms/step - loss: 0.3489 - accuracy: 0.8729 - precision: 0.8933 - recall: 0.8522 - auc: 0.9888 - f1_score: 0.8721 - val_loss: 1.4042 - val_accuracy: 0.6298 - val_precision: 0.6563 - val_recall: 0.6074 - val_auc: 0.8954 - val_f1_score: 0.6298
# Epoch 24/100
# 449/449 [==============================] - 39s 86ms/step - loss: 0.3255 - accuracy: 0.8836 - precision: 0.9016 - recall: 0.8657 - auc: 0.9898 - f1_score: 0.8832 - val_loss: 1.4996 - val_accuracy: 0.6204 - val_precision: 0.6469 - val_recall: 0.6025 - val_auc: 0.8898 - val_f1_score: 0.6234
# Epoch 25/100
# 449/449 [==============================] - 50s 112ms/step - loss: 0.3154 - accuracy: 0.8861 - precision: 0.9028 - recall: 0.8700 - auc: 0.9905 - f1_score: 0.8860 - val_loss: 1.4464 - val_accuracy: 0.6392 - val_precision: 0.6659 - val_recall: 0.6193 - val_auc: 0.8947 - val_f1_score: 0.6416
# Epoch 26/100
# 449/449 [==============================] - 52s 115ms/step - loss: 0.3059 - accuracy: 0.8891 - precision: 0.9058 - recall: 0.8747 - auc: 0.9909 - f1_score: 0.8898 - val_loss: 1.4378 - val_accuracy: 0.6308 - val_precision: 0.6561 - val_recall: 0.6103 - val_auc: 0.8950 - val_f1_score: 0.6313
# Epoch 27/100
# 449/449 [==============================] - 35s 78ms/step - loss: 0.2833 - accuracy: 0.8981 - precision: 0.9136 - recall: 0.8836 - auc: 0.9922 - f1_score: 0.8983 - val_loss: 1.4345 - val_accuracy: 0.6340 - val_precision: 0.6618 - val_recall: 0.6140 - val_auc: 0.8952 - val_f1_score: 0.6367
# Epoch 27: early stopping

# %%
model.save_weights('../Project/weights/weight4')

# %%
model.load_weights('../Project/weights/weight4')

# %% [markdown]
# # 6. Evaluate Model

# %% [markdown]
# ## 6.1 Check some Score

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_dataset)
test_evaluation = model.evaluate(test_dataset)
# Out:
# 449/449 [==============================] - 24s 52ms/step - loss: 0.2419 - accuracy: 0.9146 - precision: 0.9314 - recall: 0.8977 - auc: 0.9946 - f1_score: 0.9141
# 113/113 [==============================] - 2s 22ms/step - loss: 1.4345 - accuracy: 0.6340 - precision: 0.6618 - recall: 0.6140 - auc: 0.8952 - f1_score: 0.6372

# %%
metric_list = ["Loss","accuracy", "Precision", "Recall", "Auc", "F1_Score"]

df = pd.DataFrame(list(zip(metric_list, 
                           [round(num, 3) for num in train_evalation], 
                           [round(num, 3) for num in test_evaluation])),
                  columns=['Metric Name', 'Train', 'Validate'])

print('\n\nModel Scores\n')

HTML(df.to_html(escape=False))
# Out:
# Model Scores
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Metric Name</th>
#       <th>Train</th>
#       <th>Validate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Loss</td>
#       <td>0.242</td>
#       <td>1.435</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>accuracy</td>
#       <td>0.915</td>
#       <td>0.634</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Precision</td>
#       <td>0.931</td>
#       <td>0.662</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Recall</td>
#       <td>0.898</td>
#       <td>0.614</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Auc</td>
#       <td>0.995</td>
#       <td>0.895</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>F1_Score</td>
#       <td>0.914</td>
#       <td>0.637</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 6.2 Visualize results

# %%
hs=history.history

acc = hs['accuracy']
val_acc = hs['val_accuracy']
loss =  hs['loss']
val_loss = hs['val_loss']
auc =  hs['auc']
val_auc = hs['val_auc']
precision =hs['precision']
val_precision =hs['val_precision']
f1 = hs['f1_score']
val_f1 = hs['val_f1_score']              

plt.style.use('Solarize_Light2')

fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

ax1.plot(range(1, len(acc) + 1), acc)
ax1.plot(range(1, len(val_acc) + 1), val_acc)
ax1.set_title('History of Accuracy')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.legend(['training', 'validation'])


ax2.plot(range(1, len(loss) + 1), loss)
ax2.plot(range(1, len(val_loss) + 1), val_loss)
ax2.set_title('History of Loss')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.legend(['training', 'validation'])

ax3.plot(range(1, len(auc) + 1), auc)
ax3.plot(range(1, len(val_auc) + 1), val_auc)
ax3.set_title('History of AUC')
ax3.set_xlabel('Epochs')
ax3.set_ylabel('AUC')
ax3.legend(['training', 'validation'])

ax4.plot(range(1, len(precision) + 1), precision)
ax4.plot(range(1, len(val_precision) + 1), val_precision)
ax4.set_title('History of Precision')
ax4.set_xlabel('Epochs')
ax4.set_ylabel('Precision')
ax4.legend(['training', 'validation'])

ax5.plot(range(1, len(f1) + 1), f1)
ax5.plot(range(1, len(val_f1) + 1), val_f1)
ax5.set_title('History of F1-score')
ax5.set_xlabel('Epochs')
ax5.set_ylabel('F1 score')
ax5.legend(['training', 'validation'])

plt.show()

# %% [markdown]
# ## 6.3 Confusion Matrix

# %%
y_true = test_dataset.classes
y_pred =  model.predict(test_dataset)
y_pred= tf.argmax(y_pred, axis = 1).numpy()

cm = confusion_matrix(y_true = y_true, y_pred = y_pred)
# Out:
# 113/113 [==============================] - 5s 22ms/step

# %%
plt.rcParams['figure.figsize'] = (14,7)

plt.style.use('seaborn-darkgrid')
plt.imshow(cm, interpolation='nearest', cmap='Reds')
plt.title('Confusion matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)    

print('Confusion matrix, without normalization\n')   
print(cm)

print("\n\n")
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j],
        horizontalalignment="center",
        color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# Confusion matrix, without normalization
#
# [[143  12 129 228 158 152 136]
#  [ 15   2  21  24  17  16  16]
#  [130  14 141 267 139 182 151]
#  [233  25 253 462 266 318 217]
#  [183  18 182 320 192 193 145]
#  [177  22 199 287 174 225 163]
#  [110   9 109 208 143 161  91]]

# %%
plt.style.use('seaborn')

cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(12,6))

im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=classes, yticklabels=classes,
       title = 'Normalized confusion matrix',
       ylabel='True label',
       xlabel='Predicted label')

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")


fmt = '.2f' 
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

fig.tight_layout()
plt.show()

# %% [markdown]
# # 7. Save Model

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# # 8. Test/Predict

# %%
plt.style.use('grayscale')
plt.grid(visible=None)
img_path='../input/fer2013/test/happy/PrivateTest_3333329.jpg'
test_image=image.load_img(img_path,target_size= IMAGE_SIZE,color_mode='grayscale')
test_image=image.img_to_array(test_image)
print(test_image.shape)
plt.imshow(test_image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\28573\Desktop\machine\FaceDetection\vgg16.ipynb 单元格 34 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/28573/Desktop/machine/FaceDetection/vgg16.ipynb#X44sZmlsZQ%3D%3D?line=1'>2</a> plt.grid(visible=None)
#       <a href='vscode-notebook-cell:/c%3A/Users/28573/Desktop/machine/FaceDetection/vgg16.ipynb#X44sZmlsZQ%3D%3D?line=2'>3</a> img_path='../input/fer2013/test/happy/PrivateTest_3333329.jpg'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/28573/Desktop/machine/FaceDetection/vgg16.ipynb#X44sZmlsZQ%3D%3D?line=3'>4</a> test_image=image.load_img(img_path,target_size= IMAGE_SIZE,color_mode='grayscale')
#       <a href='vscode-notebook-cell:/c%3A/Users/28573/Desktop/machine/FaceDetection/vgg16.ipynb#X44sZmlsZQ%3D%3D?line=4'>5</a> test_image=image.img_to_array(test_image)
#       <a href='vscode-notebook-cell:/c%3A/Users/28573/Desktop/machine/FaceDetection/vgg16.ipynb#X44sZmlsZQ%3D%3D?line=5'>6</a> print(test_image.shape)
#
# File c:\Users\28573\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../input/fer2013/test/happy/PrivateTest_3333329.jpg'

# %%
img=image.load_img(img_path,target_size=IMAGE_SIZE)
img = np.expand_dims(img, axis=0)
print(img.shape)
# Out:
# (1, 48, 48, 3)

# %%
result=model.predict(img)
print(result[0])
y_pred=np.argmax(result[0])
print('The person facial emotion is:',classes[y_pred])
# Out:
# [0. 0. 0. 1. 0. 0. 0.]
# The person facial emotion is: Happy

# %% [markdown]
# ### How to predict a single image with Keras ImageDataGenerator?
# https://stackoverflow.com/questions/63703280/how-to-predict-a-single-image-with-keras-imagedatagenerator

# %% [markdown]
# # Best model V23
